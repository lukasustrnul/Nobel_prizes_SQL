# %% [markdown]
# # Nobel Prize analysis in SQL
#
# ## Import of data, libraries and making it ready to work with SQL

# %%
# import librariesa
import pandas as pd
import sqlite3

# %%
# install the ipython-sql libray
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython-sql in c:\users\lukáš\appdata\roaming\python\python39\site-packages (0.5.0)
# Requirement already satisfied: ipython-genutils in c:\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: ipython in c:\anaconda3\lib\site-packages (from ipython-sql) (7.31.1)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from ipython-sql) (2.0.26)
# Requirement already satisfied: sqlparse in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: backcall in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (63.4.1)
# Requirement already satisfied: traitlets>=4.2 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.5)
# Requirement already satisfied: pygments in c:\users\lukáš\appdata\roaming\python\python39\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pickleshare in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: wcwidth in c:\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)

# %%
# read the csv file to pandas dataframe
df = pd.read_csv('nobel.csv')

# %%
# We will use sqlite3 library and create a connection
cnn = sqlite3.connect('jupyter_sql_nobel.db')
df.to_sql('nobel', cnn, if_exists='replace')
# %load_ext sql
# %sql sqlite:///jupyter_sql_nobel.db

# %% [markdown]
# ## Check of the data

# %%
# %%sql
# /* check general information about the data*/
# PRAGMA table_info(nobel);
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'year', 'INTEGER', 0, None, 0),
#  (2, 'category', 'TEXT', 0, None, 0),
#  (3, 'prize', 'TEXT', 0, None, 0),
#  (4, 'motivation', 'TEXT', 0, None, 0),
#  (5, 'prize_share', 'TEXT', 0, None, 0),
#  (6, 'laureate_id', 'INTEGER', 0, None, 0),
#  (7, 'laureate_type', 'TEXT', 0, None, 0),
#  (8, 'full_name', 'TEXT', 0, None, 0),
#  (9, 'birth_date', 'TEXT', 0, None, 0),
#  (10, 'birth_city', 'TEXT', 0, None, 0),
#  (11, 'birth_country', 'TEXT', 0, None, 0),
#  (12, 'sex', 'TEXT', 0, None, 0),
#  (13, 'organization_name', 'TEXT', 0, None, 0),
#  (14, 'organization_city', 'TEXT', 0, None, 0),
#  (15, 'organization_country', 'TEXT', 0, None, 0),
#  (16, 'death_date', 'TEXT', 0, None, 0),
#  (17, 'death_city', 'TEXT', 0, None, 0),
#  (18, 'death_country', 'TEXT', 0, None, 0)]

# %%
# %%sql
# /* check first row to get idea how the data looks */
# SELECT *
# FROM nobel
# LIMIT 1;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(0, 1901, 'Chemistry', 'The Nobel Prize in Chemistry 1901', '"in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions"', '1/1', 160, 'Individual', "Jacobus Henricus van 't Hoff", '1852-08-30', 'Rotterdam', 'Netherlands', 'Male', 'Berlin University', 'Berlin', 'Germany', '1911-03-01', 'Berlin', 'Germany')]

# %%
# %%sql
# /* We are going to use birth_date and death_date in many queries;
# therefore, it is important to check that values are valid
# and we can do calculations with them using date and time functions.
# SQLite does not have a storage class set aside for storing dates and/or times.
# Instead, the built-in Date And Time Functions of SQLite are capable of storing
# dates and times as TEXT, REAL, or INTEGER values.
# See here: https://www.sqlite.org/datatype3.html */
#
#
# SELECT
# laureate_id,
# birth_date,
# strftime('%Y',birth_date) AS birth_strf
# FROM nobel
# WHERE birth_date IS NOT NULL AND birth_strf IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(967, '1993-00-00', None),
#  (969, '1955-00-00', None),
#  (986, '1949-00-00', None),
#  (998, '1967-00-00', None),
#  (1004, '1948-00-00', None),
#  (1006, '1961-00-00', None),
#  (1007, '1956-00-00', None),
#  (1016, '1954-00-00', None),
#  (1029, '1961-00-00', None),
#  (1030, '1943-00-00', None),
#  (1031, '1945-00-00', None),
#  (1034, '1946-00-00', None)]

# %%
# %%sql
# /* Same check as in previous cell but for the death date*/
#
#
# SELECT
# laureate_id,
# death_date,
# strftime('%Y',death_date) AS death_strf
# FROM nobel
# WHERE death_date IS NOT NULL AND death_strf IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# []

# %% [markdown]
# ### Birth_date issue and its solution
# We can see that death dates are not cousing problems but some birth dates has a format YYYY-00-00. This is not recognized by time and date functions (e.g.: strftime, julianday) as a date and returns NULL values instead of year if we use strftime('%Y',birth_date). Therefore, these birth dates cannot be used to calculate age.
#
# To clean this, the problematic birth_date values has to be removed or the dates changed to valid date. I have decided for the latter. If we change YYYY-00-00 to YYYY-07-01 then the birth_date will be almost exactly in the middle of the year and there will be in the worst case half year error for each of the laureates with edited birth_date. However, this update of nobel table will be done later after we will check if there are some dates on which was born the most laureates.

# %% [markdown]
# ### Checking of missing values

# %%
# %%sql
# /* count total number of rows and number of "NOT NULL" values
# in each column to get overview how complete are the data */
#
# SELECT
#     COUNT(*) AS total_nr,
#     COUNT(year) AS year,
#     COUNT(category) AS category,
#     COUNT(prize) AS prize,
#     COUNT(motivation) AS motivation,
#     COUNT(prize_share) AS share,
#     COUNT(laureate_id) AS laureate_id,
#     COUNT(laureate_type) AS laureate_type,
#     COUNT(full_name) AS full_name,
#     COUNT(birth_date) AS birth_date,
#     COUNT(birth_city) AS birth_city,
#     COUNT(birth_country) AS birth_country,
#     COUNT(sex) AS sex,
#     COUNT(organization_name) AS organization_name,
#     COUNT(organization_city) AS organization_city,
#     COUNT(organization_country) AS organization_country,
#     COUNT(death_date) AS death_date,
#     COUNT(death_city) AS death_city,
#     COUNT(death_country) AS death_country
# FROM nobel;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(1000, 1000, 1000, 1000, 912, 1000, 1000, 1000, 1000, 968, 964, 969, 970, 736, 735, 735, 596, 579, 585)]

# %% [markdown]
# ### Overview of missing values
# We can see that currently (Fabruary 2024) was historically awarded 1000 Nobel Prizes. First column with significant amount of missing values is 'motivation'. Further, there are around 40 values missing in columns related to birth. Generally, it would not be surprising if the birth_date or place of birth would be unknow for few people. Most likely, where is missing birth_country there will be also missing information on birth_city, however, it should be checked if the same rows have also problem with missing birth_date. Next we can see that there is missing information on sex at 30 cases which can be due to the fact that some prizes were awarded to institutions. Then, there is significant amount of data missing in columns related to organization and it will be worth of finding out reasons for that. Finally, lots of values are missing in relation to deaths, probably a big portion of awarded people is still alive or the data are not up to date. However, it is not focus of this work to check if any death_date is missing incorrectly and we will just assume that missing death_date means that the person is still alive.

# %%
# %%sql
# /* check columns with missing data to find out if there is any reason for that
# or if they have something in common. Lets check motivation column first */
#
# SELECT *
# FROM nobel
# WHERE motivation IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(3, 1901, 'Peace', 'The Nobel Peace Prize 1901', None, '1/2', 462, 'Individual', 'Jean Henry Dunant', '1828-05-08', 'Geneva', 'Switzerland', 'Male', None, None, None, '1910-10-30', 'Heiden', 'Switzerland'),
#  (4, 1901, 'Peace', 'The Nobel Peace Prize 1901', None, '1/2', 463, 'Individual', 'Frédéric Passy', '1822-05-20', 'Paris', 'France', 'Male', None, None, None, '1912-06-12', 'Paris', 'France'),
#  (9, 1902, 'Peace', 'The Nobel Peace Prize 1902', None, '1/2', 464, 'Individual', 'Élie Ducommun', '1833-02-19', 'Geneva', 'Switzerland', 'Male', None, None, None, '1906-12-07', 'Bern', 'Switzerland'),
#  (10, 1902, 'Peace', 'The Nobel Peace Prize 1902', None, '1/2', 465, 'Individual', 'Charles Albert Gobat', '1843-05-21', 'Tramelan', 'Switzerland', 'Male', None, None, None, '1914-03-16', 'Bern', 'Switzerland'),
#  (16, 1903, 'Peace', 'The Nobel Peace Prize 1903', None, '1/1', 466, 'Individual', 'William Randal Cremer', '1828-03-18', 'Fareham', 'United Kingdom', 'Male', None, None, None, '1908-07-22', 'London', 'United Kingdom'),
#  (24, 1904, 'Peace', 'The Nobel Peace Prize 1904', None, '1/1', 467, 'Organization', 'Institut de droit international (Institute of International Law)', None, None, None, None, None, None, None, None, None, None),
#  (29, 1905, 'Peace', 'The Nobel Peace Prize 1905', None, '1/1', 468, 'Individual', 'Baroness Bertha Sophie Felicita von Suttner, née Countess Kinsky von Chinic und Tettau', '1843-06-09', 'Prague', 'Austrian Empire (Czech Republic)', 'Female', None, None, None, '1914-06-21', 'Vienna', 'Austria'),
#  (35, 1906, 'Peace', 'The Nobel Peace Prize 1906', None, '1/1', 470, 'Individual', 'Theodore Roosevelt', '1858-10-27', 'New York, NY', 'United States of America', 'Male', None, None, None, '1919-01-06', 'Oyster Bay, NY', 'United States of America'),
#  (40, 1907, 'Peace', 'The Nobel Peace Prize 1907', None, '1/2', 471, 'Individual', 'Ernesto Teodoro Moneta', '1833-09-20', 'Milan', 'Austrian Empire (Italy)', 'Male', None, None, None, '1918-02-10', 'Milan', 'Italy'),
#  (41, 1907, 'Peace', 'The Nobel Peace Prize 1907', None, '1/2', 472, 'Individual', 'Louis Renault', '1843-05-21', 'Autun', 'France', 'Male', 'Sorbonne University', 'Paris', 'France', '1918-02-08', 'Barbizon', 'France'),
#  (47, 1908, 'Peace', 'The Nobel Peace Prize 1908', None, '1/2', 473, 'Individual', 'Klas Pontus Arnoldson', '1844-10-27', 'Gothenburg', 'Sweden', 'Male', None, None, None, '1916-02-20', 'Stockholm', 'Sweden'),
#  (48, 1908, 'Peace', 'The Nobel Peace Prize 1908', None, '1/2', 474, 'Individual', 'Fredrik Bajer', '1837-04-21', 'Næstved', 'Denmark', 'Male', None, None, None, '1922-01-22', 'Copenhagen', 'Denmark'),
#  (53, 1909, 'Peace', 'The Nobel Peace Prize 1909', None, '1/2', 475, 'Individual', 'Auguste Marie François Beernaert', '1829-07-26', 'Ostend', 'Belgium', 'Male', None, None, None, '1912-10-06', 'Lucerne', 'Switzerland'),
#  (54, 1909, 'Peace', 'The Nobel Peace Prize 1909', None, '1/2', 476, 'Individual', "Paul Henri Benjamin Balluet d'Estournelles de Constant, Baron de Constant de Rebecque", '1852-11-22', 'La Flèche', 'France', 'Male', None, None, None, '1924-05-15', 'Paris', 'France'),
#  (60, 1910, 'Peace', 'The Nobel Peace Prize 1910', None, '1/1', 477, 'Organization', 'Bureau international permanent de la Paix (Permanent International Peace Bureau)', None, None, None, None, None, None, None, None, None, None),
#  (65, 1911, 'Peace', 'The Nobel Peace Prize 1911', None, '1/2', 478, 'Individual', 'Tobias Michael Carel Asser', '1838-04-28', 'Amsterdam', 'Netherlands', 'Male', None, None, None, '1913-07-29', 'the Hague', 'Netherlands'),
#  (66, 1911, 'Peace', 'The Nobel Peace Prize 1911', None, '1/2', 479, 'Individual', 'Alfred Hermann Fried', '1864-11-11', 'Vienna', 'Austria', 'Male', None, None, None, '1921-05-05', 'Vienna', 'Austria'),
#  (72, 1912, 'Peace', 'The Nobel Peace Prize 1912', None, '1/1', 480, 'Individual', 'Elihu Root', '1845-02-15', 'Clinton, NY', 'United States of America', 'Male', None, None, None, '1937-02-07', 'New York, NY', 'United States of America'),
#  (77, 1913, 'Peace', 'The Nobel Peace Prize 1913', None, '1/1', 481, 'Individual', 'Henri La Fontaine', '1854-04-22', 'Brussels', 'Belgium', 'Male', None, None, None, '1943-05-14', 'Brussels', 'Belgium'),
#  (89, 1917, 'Peace', 'The Nobel Peace Prize 1917', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (95, 1919, 'Peace', 'The Nobel Peace Prize 1919', None, '1/1', 483, 'Individual', 'Thomas Woodrow Wilson', '1856-12-28', 'Staunton, VA', 'United States of America', 'Male', None, None, None, '1924-02-03', 'Washington, DC', 'United States of America'),
#  (100, 1920, 'Peace', 'The Nobel Peace Prize 1920', None, '1/1', 484, 'Individual', 'Léon Victor Auguste Bourgeois', '1851-05-21', 'Paris', 'France', 'Male', None, None, None, '1925-09-29', 'Épernay', 'France'),
#  (104, 1921, 'Peace', 'The Nobel Peace Prize 1921', None, '1/2', 485, 'Individual', 'Karl Hjalmar Branting', '1860-11-23', 'Stockholm', 'Sweden', 'Male', None, None, None, '1925-02-24', 'Stockholm', 'Sweden'),
#  (105, 1921, 'Peace', 'The Nobel Peace Prize 1921', None, '1/2', 486, 'Individual', 'Christian Lous Lange', '1869-09-17', 'Stavanger', 'Norway', 'Male', None, None, None, '1938-12-11', 'Oslo', 'Norway'),
#  (111, 1922, 'Peace', 'The Nobel Peace Prize 1922', None, '1/1', 487, 'Individual', 'Fridtjof Nansen', '1861-10-10', 'Kristiania (Oslo)', 'Norway', 'Male', None, None, None, '1930-05-13', 'Oslo', 'Norway'),
#  (123, 1925, 'Peace', 'The Nobel Peace Prize 1925', None, '1/2', 488, 'Individual', 'Sir Austen Chamberlain', '1863-10-16', 'Birmingham', 'United Kingdom', 'Male', None, None, None, '1937-03-16', 'London', 'United Kingdom'),
#  (124, 1925, 'Peace', 'The Nobel Peace Prize 1925', None, '1/2', 489, 'Individual', 'Charles Gates Dawes', '1865-08-27', 'Marietta, OH', 'United States of America', 'Male', None, None, None, '1951-04-23', 'Evanston, IL', 'United States of America'),
#  (130, 1926, 'Peace', 'The Nobel Peace Prize 1926', None, '1/2', 490, 'Individual', 'Aristide Briand', '1862-03-28', 'Nantes', 'France', 'Male', None, None, None, '1932-03-07', 'Paris', 'France'),
#  (131, 1926, 'Peace', 'The Nobel Peace Prize 1926', None, '1/2', 491, 'Individual', 'Gustav Stresemann', '1878-05-10', 'Berlin', 'Germany', 'Male', None, None, None, '1929-10-03', 'Berlin', 'Germany'),
#  (136, 1927, 'Peace', 'The Nobel Peace Prize 1927', None, '1/2', 492, 'Individual', 'Ferdinand Buisson', '1841-12-20', 'Paris', 'France', 'Male', None, None, None, '1932-02-16', 'Thieuloy-Saint-Antoine', 'France'),
#  (137, 1927, 'Peace', 'The Nobel Peace Prize 1927', None, '1/2', 493, 'Individual', 'Ludwig Quidde', '1858-03-23', 'Bremen', 'Germany', 'Male', None, None, None, '1941-03-04', 'Geneva', 'Switzerland'),
#  (149, 1929, 'Peace', 'The Nobel Peace Prize 1929', None, '1/1', 494, 'Individual', 'Frank Billings Kellogg', '1856-12-22', 'Potsdam, NY', 'United States of America', 'Male', None, None, None, '1937-12-21', 'St. Paul, MN', 'United States of America'),
#  (154, 1930, 'Peace', 'The Nobel Peace Prize 1930', None, '1/1', 495, 'Individual', 'Lars Olof Jonathan (Nathan) Söderblom', '1866-01-15', 'Trönö', 'Sweden', 'Male', None, None, None, '1931-07-12', 'Uppsala', 'Sweden'),
#  (160, 1931, 'Peace', 'The Nobel Peace Prize 1931', None, '1/2', 496, 'Individual', 'Jane Addams', '1860-09-06', 'Cedarville, IL', 'United States of America', 'Female', None, None, None, '1935-05-21', 'Chicago, IL', 'United States of America'),
#  (161, 1931, 'Peace', 'The Nobel Peace Prize 1931', None, '1/2', 497, 'Individual', 'Nicholas Murray Butler', '1862-04-02', 'Elizabeth, NJ', 'United States of America', 'Male', 'Columbia University', 'New York, NY', 'United States of America', '1947-12-07', 'New York, NY', 'United States of America'),
#  (169, 1933, 'Peace', 'The Nobel Peace Prize 1933', None, '1/1', 498, 'Individual', 'Sir Norman Angell (Ralph Lane)', '1872-12-26', 'Holbeach', 'United Kingdom', 'Male', None, None, None, '1967-10-07', 'Croydon', 'United Kingdom'),
#  (177, 1934, 'Peace', 'The Nobel Peace Prize 1934', None, '1/1', 499, 'Individual', 'Arthur Henderson', '1863-09-13', 'Glasgow', 'Scotland', 'Male', None, None, None, '1935-10-20', 'London', 'United Kingdom'),
#  (181, 1935, 'Peace', 'The Nobel Peace Prize 1935', None, '1/1', 500, 'Individual', 'Carl von Ossietzky', '1889-10-03', 'Hamburg', 'Germany', 'Male', None, None, None, '1938-05-04', 'Berlin', 'Germany'),
#  (187, 1936, 'Peace', 'The Nobel Peace Prize 1936', None, '1/1', 501, 'Individual', 'Carlos Saavedra Lamas', '1878-11-01', 'Buenos Aires', 'Argentina', 'Male', None, None, None, '1959-05-05', 'Buenos Aires', 'Argentina'),
#  (194, 1937, 'Peace', 'The Nobel Peace Prize 1937', None, '1/1', 502, 'Individual', 'Cecil of Chelwood, Viscount (Lord Edgar Algernon Robert Gascoyne Cecil)', '1864-09-14', 'London', 'United Kingdom', 'Male', None, None, None, '1958-11-24', 'Tunbridge Wells', 'United Kingdom'),
#  (200, 1938, 'Peace', 'The Nobel Peace Prize 1938', None, '1/1', 503, 'Organization', 'Office international Nansen pour les Réfugiés (Nansen International Office for Refugees)', None, None, None, None, None, None, None, None, None, None),
#  (215, 1944, 'Peace', 'The Nobel Peace Prize 1944', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (222, 1945, 'Peace', 'The Nobel Peace Prize 1945', None, '1/1', 505, 'Individual', 'Cordell Hull', '1871-10-02', 'Olympus, TN', 'United States of America', 'Male', None, None, None, '1955-07-23', 'Bethesda, MD', 'United States of America'),
#  (229, 1946, 'Peace', 'The Nobel Peace Prize 1946', None, '1/2', 506, 'Individual', 'Emily Greene Balch', '1867-01-08', 'Jamaica Plain, MA (Boston)', 'United States of America', 'Female', None, None, None, '1961-01-09', 'Cambridge, MA', 'United States of America'),
#  (230, 1946, 'Peace', 'The Nobel Peace Prize 1946', None, '1/2', 507, 'Individual', 'John Raleigh Mott', '1865-05-25', 'Livingston Manor, NY', 'United States of America', 'Male', None, None, None, '1955-01-31', None, 'United States of America'),
#  (237, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 508, 'Organization', 'Friends Service Council (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (238, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 509, 'Organization', 'American Friends Service Committee (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (248, 1949, 'Peace', 'The Nobel Peace Prize 1949', None, '1/1', 510, 'Individual', 'Lord (John) Boyd Orr of Brechin', '1880-09-23', 'Kilmaurs', 'Scotland', 'Male', None, None, None, '1971-06-25', 'Edzell', 'Scotland'),
#  (256, 1950, 'Peace', 'The Nobel Peace Prize 1950', None, '1/1', 511, 'Individual', 'Ralph Bunche', '1904-08-07', 'Detroit, MI', 'United States of America', 'Male', 'Harvard University', 'Cambridge, MA', 'United States of America', '1971-12-09', 'New York, NY', 'United States of America'),
#  (262, 1951, 'Peace', 'The Nobel Peace Prize 1951', None, '1/1', 512, 'Individual', 'Léon Jouhaux', '1879-07-01', 'Paris', 'France', 'Male', None, None, None, '1954-04-28', 'Paris', 'France'),
#  (269, 1952, 'Peace', 'The Nobel Peace Prize 1952', None, '1/1', 513, 'Individual', 'Albert Schweitzer', '1875-01-14', 'Kaysersberg', 'Germany (France)', 'Male', None, None, None, '1965-09-04', 'Lambaréné', 'Gabon'),
#  (276, 1953, 'Peace', 'The Nobel Peace Prize 1953', None, '1/1', 514, 'Individual', 'George Catlett Marshall', '1880-12-31', 'Uniontown, PA', 'United States of America', 'Male', None, None, None, '1959-10-16', 'Washington, DC', 'United States of America'),
#  (283, 1954, 'Peace', 'The Nobel Peace Prize 1954', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (303, 1957, 'Peace', 'The Nobel Peace Prize 1957', None, '1/1', 516, 'Individual', 'Lester Bowles Pearson', '1897-04-23', 'Toronto', 'Canada', 'Male', None, None, None, '1972-12-27', 'Ottawa', 'Canada'),
#  (311, 1958, 'Peace', 'The Nobel Peace Prize 1958', None, '1/1', 517, 'Individual', 'Georges Pire', '1910-02-10', 'Dinant', 'Belgium', 'Male', None, None, None, '1969-01-30', 'Leuven', 'Belgium'),
#  (319, 1959, 'Peace', 'The Nobel Peace Prize 1959', None, '1/1', 518, 'Individual', 'Philip J. Noel-Baker', '1889-11-01', 'London', 'United Kingdom', 'Male', None, None, None, '1982-10-08', 'London', 'United Kingdom'),
#  (326, 1960, 'Peace', 'The Nobel Peace Prize 1960', None, '1/1', 519, 'Individual', 'Albert John Lutuli', '1898-01-01', 'Bulawayo', 'Southern Rhodesia (Zimbabwe)', 'Male', None, None, None, '1967-07-21', 'Stanger', 'South Africa'),
#  (331, 1961, 'Peace', 'The Nobel Peace Prize 1961', None, '1/1', 520, 'Individual', 'Dag Hjalmar Agne Carl Hammarskjöld', '1905-07-29', 'Jönköping', 'Sweden', 'Male', None, None, None, '1961-09-18', 'Ndola', 'Northern Rhodesia (Zambia)'),
#  (340, 1962, 'Peace', 'The Nobel Peace Prize 1962', None, '1/1', 217, 'Individual', 'Linus Carl Pauling', '1901-02-28', 'Portland, OR', 'United States of America', 'Male', 'California Institute of Technology (Caltech)', 'Pasadena, CA', 'United States of America', '1994-08-19', 'Big Sur, CA', 'United States of America'),
#  (348, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (349, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 523, 'Organization', 'Ligue des Sociétés de la Croix-Rouge (League of Red Cross Societies)', None, None, None, None, None, None, None, None, None, None),
#  (357, 1964, 'Peace', 'The Nobel Peace Prize 1964', None, '1/1', 524, 'Individual', 'Martin Luther King Jr.', '1929-01-15', 'Atlanta, GA', 'United States of America', 'Male', None, None, None, '1968-04-04', 'Memphis, TN', 'United States of America'),
#  (366, 1965, 'Peace', 'The Nobel Peace Prize 1965', None, '1/1', 525, 'Organization', "United Nations Children's Fund (UNICEF)", None, None, None, None, None, None, None, None, None, None),
#  (389, 1968, 'Peace', 'The Nobel Peace Prize 1968', None, '1/1', 526, 'Individual', 'René Cassin', '1887-10-05', 'Bayonne', 'France', 'Male', None, None, None, '1976-02-20', 'Paris', 'France'),
#  (399, 1969, 'Peace', 'The Nobel Peace Prize 1969', None, '1/1', 527, 'Organization', 'International Labour Organization (I.L.O.)', None, None, None, None, None, None, None, None, None, None),
#  (407, 1970, 'Peace', 'The Nobel Peace Prize 1970', None, '1/1', 528, 'Individual', 'Norman E. Borlaug', '1914-03-25', 'Cresco, IA', 'United States of America', 'Male', None, None, None, '2009-09-12', 'Dallas, TX', 'United States of America'),
#  (414, 1971, 'Peace', 'The Nobel Peace Prize 1971', None, '1/1', 529, 'Individual', 'Willy Brandt', '1913-12-18', 'Lübeck', 'Germany', 'Male', None, None, None, '1992-10-08', 'Unkel', 'Germany'),
#  (434, 1973, 'Peace', 'The Nobel Peace Prize 1973', None, '1/2', 530, 'Individual', 'Henry A. Kissinger', '1923-05-27', 'Fürth', 'Germany', 'Male', None, None, None, None, None, None),
#  (435, 1973, 'Peace', 'The Nobel Peace Prize 1973', None, '1/2', 531, 'Organization', 'Le Duc Tho', '1911-10-14', 'Nam Ha province', 'Vietnam', 'Male', None, None, None, '1990-10-13', 'Hanoi', 'Vietnam'),
#  (447, 1974, 'Peace', 'The Nobel Peace Prize 1974', None, '1/2', 532, 'Individual', 'Seán MacBride', '1904-01-26', 'Paris', 'France', 'Male', None, None, None, '1988-01-15', 'Dublin', 'Ireland'),
#  (448, 1974, 'Peace', 'The Nobel Peace Prize 1974', None, '1/2', 533, 'Individual', 'Eisaku Sato', '1901-03-27', 'Tabuse', 'Japan', 'Male', None, None, None, '1975-06-03', 'Tokyo', 'Japan'),
#  (459, 1975, 'Peace', 'The Nobel Peace Prize 1975', None, '1/1', 534, 'Individual', 'Andrei Dmitrievich Sakharov', '1921-05-21', 'Moscow', 'Russia', 'Male', None, None, None, '1989-12-14', 'Moscow', 'Union of Soviet Socialist Republics (Russia)'),
#  (468, 1976, 'Peace', 'The Nobel Peace Prize 1976', None, '1/2', 535, 'Individual', 'Betty Williams', '1943-05-22', 'Belfast', 'Northern Ireland', 'Female', None, None, None, None, None, None),
#  (469, 1976, 'Peace', 'The Nobel Peace Prize 1976', None, '1/2', 536, 'Individual', 'Mairead Corrigan', '1944-01-27', 'Belfast', 'Northern Ireland', 'Female', None, None, None, None, None, None),
#  (479, 1977, 'Peace', 'The Nobel Peace Prize 1977', None, '1/1', 537, 'Organization', 'Amnesty International', None, None, None, None, None, None, None, None, None, None),
#  (489, 1978, 'Peace', 'The Nobel Peace Prize 1978', None, '1/2', 538, 'Individual', 'Mohamed Anwar al-Sadat', '1918-12-25', 'Mit Abu al-Kawm', 'Egypt', 'Male', None, None, None, '1981-10-06', 'Cairo', 'Egypt'),
#  (490, 1978, 'Peace', 'The Nobel Peace Prize 1978', None, '1/2', 539, 'Individual', 'Menachem Begin', '1913-08-16', 'Brest Litovsk', 'Russian Empire (Belarus)', 'Male', None, None, None, '1992-03-09', 'Tel Aviv', 'Israel'),
#  (501, 1979, 'Peace', 'The Nobel Peace Prize 1979', None, '1/1', 540, 'Organization', 'Mother Teresa', '1910-08-26', 'Uskup (Skopje)', 'Ottoman Empire (Republic of Macedonia)', 'Female', None, None, None, '1997-09-05', 'Calcutta', 'India'),
#  (513, 1980, 'Peace', 'The Nobel Peace Prize 1980', None, '1/1', 541, 'Individual', 'Adolfo Pérez Esquivel', '1931-11-26', 'Buenos Aires', 'Argentina', 'Male', None, None, None, None, None, None),
#  (523, 1981, 'Peace', 'The Nobel Peace Prize 1981', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (533, 1982, 'Peace', 'The Nobel Peace Prize 1982', None, '1/2', 543, 'Individual', 'Alva Myrdal', '1902-01-31', 'Uppsala', 'Sweden', 'Female', None, None, None, '1986-02-01', 'Stockholm', 'Sweden'),
#  (534, 1982, 'Peace', 'The Nobel Peace Prize 1982', None, '1/2', 544, 'Individual', 'Alfonso García Robles', '1911-03-20', 'Zamora', 'Mexico', 'Male', None, None, None, '1991-09-02', 'Mexico City', 'Mexico'),
#  (540, 1983, 'Peace', 'The Nobel Peace Prize 1983', None, '1/1', 545, 'Individual', 'Lech Walesa', '1943-09-29', 'Popowo', 'Poland', 'Male', None, None, None, None, None, None),
#  (549, 1984, 'Peace', 'The Nobel Peace Prize 1984', None, '1/1', 546, 'Individual', 'Desmond Mpilo Tutu', '1931-10-07', 'Klerksdorp', 'South Africa', 'Male', None, None, None, None, None, None),
#  (558, 1985, 'Peace', 'The Nobel Peace Prize 1985', None, '1/1', 547, 'Organization', 'International Physicians for the Prevention of Nuclear War', None, None, None, None, None, None, None, None, None, None),
#  (567, 1986, 'Peace', 'The Nobel Peace Prize 1986', None, '1/1', 548, 'Individual', 'Elie Wiesel', '1928-09-30', 'Sighet', 'Romania', 'Male', None, None, None, '2016-07-02', 'New York, NY', 'United States of America'),
#  (588, 1988, 'Peace', 'The Nobel Peace Prize 1988', None, '1/1', 550, 'Organization', 'United Nations Peacekeeping Forces', None, None, None, None, None, None, None, None, None, None),
#  (598, 1989, 'Peace', 'The Nobel Peace Prize 1989', None, '1/1', 551, 'Organization', 'The 14th Dalai Lama (Tenzin Gyatso)', '1935-07-06', 'Taktser', "Tibet (People's Republic of China)", 'Male', None, None, None, None, None, None)]

# %%
# %%sql
# /* It seems that motivation was not announced for The Nobel Peace Prizes until year 1990.
# We can double check it by counting missing motivation within Peace category. Indeed, 88+912 = 1000*/
# SELECT COUNT(*)
# FROM nobel
# WHERE motivation IS NULL AND category = 'Peace';
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(88,)]

# %%
# %%sql
# /* Was there any Nobel Peace Prize with motivation before 1990? */
# SELECT *
# FROM nobel
# WHERE category = 'Peace' AND motivation IS NOT NULL AND year<1990;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(577, 1987, 'Peace', 'The Nobel Peace Prize 1987', '"for his work for peace in Central America, efforts which led to the accord signed in Guatemala on August 7 this year"', '1/1', 549, 'Individual', 'Oscar Arias Sánchez', '1941-09-13', 'Heredia', 'Costa Rica', 'Male', None, None, None, None, None, None)]

# %%
# %%sql
# /* check columns with missing data to find out if there is any reason for that
# or if they have something in common. Lets check birth and sex related columns now */
#
# SELECT COUNT(*)
# FROM nobel
# WHERE birth_date IS NULL
# OR birth_city IS NULL
# OR birth_country IS NULL
# OR sex IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(38,)]

# %%
# %%sql
# /* From earlier we know that there was 30-40 missing values
# in each of the columns related to birth or sex.
# From the result of previous query we can conclude that most of these
# missing values are occuring on the same rows.
# Lets see full information if there is anything in common */
#
# SELECT *
# FROM nobel
# WHERE birth_date IS NULL
# OR birth_city IS NULL
# OR birth_country IS NULL
# OR sex IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(24, 1904, 'Peace', 'The Nobel Peace Prize 1904', None, '1/1', 467, 'Organization', 'Institut de droit international (Institute of International Law)', None, None, None, None, None, None, None, None, None, None),
#  (60, 1910, 'Peace', 'The Nobel Peace Prize 1910', None, '1/1', 477, 'Organization', 'Bureau international permanent de la Paix (Permanent International Peace Bureau)', None, None, None, None, None, None, None, None, None, None),
#  (89, 1917, 'Peace', 'The Nobel Peace Prize 1917', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (200, 1938, 'Peace', 'The Nobel Peace Prize 1938', None, '1/1', 503, 'Organization', 'Office international Nansen pour les Réfugiés (Nansen International Office for Refugees)', None, None, None, None, None, None, None, None, None, None),
#  (215, 1944, 'Peace', 'The Nobel Peace Prize 1944', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (237, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 508, 'Organization', 'Friends Service Council (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (238, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 509, 'Organization', 'American Friends Service Committee (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (283, 1954, 'Peace', 'The Nobel Peace Prize 1954', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (348, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (349, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 523, 'Organization', 'Ligue des Sociétés de la Croix-Rouge (League of Red Cross Societies)', None, None, None, None, None, None, None, None, None, None),
#  (366, 1965, 'Peace', 'The Nobel Peace Prize 1965', None, '1/1', 525, 'Organization', "United Nations Children's Fund (UNICEF)", None, None, None, None, None, None, None, None, None, None),
#  (399, 1969, 'Peace', 'The Nobel Peace Prize 1969', None, '1/1', 527, 'Organization', 'International Labour Organization (I.L.O.)', None, None, None, None, None, None, None, None, None, None),
#  (479, 1977, 'Peace', 'The Nobel Peace Prize 1977', None, '1/1', 537, 'Organization', 'Amnesty International', None, None, None, None, None, None, None, None, None, None),
#  (523, 1981, 'Peace', 'The Nobel Peace Prize 1981', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (558, 1985, 'Peace', 'The Nobel Peace Prize 1985', None, '1/1', 547, 'Organization', 'International Physicians for the Prevention of Nuclear War', None, None, None, None, None, None, None, None, None, None),
#  (588, 1988, 'Peace', 'The Nobel Peace Prize 1988', None, '1/1', 550, 'Organization', 'United Nations Peacekeeping Forces', None, None, None, None, None, None, None, None, None, None),
#  (659, 1995, 'Peace', 'The Nobel Peace Prize 1995', '"for their efforts to diminish the part played by nuclear arms in international politics and, in the longer run, to eliminate such arms"', '1/2', 561, 'Organization', 'Pugwash Conferences on Science and World Affairs', None, None, None, None, None, None, None, None, None, None),
#  (682, 1997, 'Peace', 'The Nobel Peace Prize 1997', '"for their work for the banning and clearing of anti-personnel mines"', '1/2', 564, 'Organization', 'International Campaign to Ban Landmines (ICBL)', None, None, None, None, None, None, None, None, None, None),
#  (703, 1999, 'Peace', 'The Nobel Peace Prize 1999', '"in recognition of the organization\'s pioneering humanitarian work on several continents"', '1/1', 568, 'Organization', 'Médecins Sans Frontières', None, None, None, None, None, None, None, None, None, None),
#  (725, 2001, 'Literature', 'The Nobel Prize in Literature 2001', '"for having united perceptive narrative and incorruptible scrutiny in works that compel us to see the presence of suppressed histories"', '1/1', 747, 'Individual', 'Sir Vidiadhar Surajprasad Naipaul', '1932-08-17', None, 'Trinidad', 'Male', None, None, None, None, None, None),
#  (729, 2001, 'Peace', 'The Nobel Peace Prize 2001', '"for their work for a better organized and more peaceful world"', '1/2', 748, 'Organization', 'United Nations (U.N.)', None, None, None, None, None, None, None, None, None, None),
#  (778, 2005, 'Peace', 'The Nobel Peace Prize 2005', '"for their efforts to prevent nuclear energy from being used for military purposes and to ensure that nuclear energy for peaceful purposes is used in the safest possible way"', '1/2', 797, 'Organization', 'International Atomic Energy Agency (IAEA)', None, None, None, None, None, None, None, None, None, None),
#  (789, 2006, 'Peace', 'The Nobel Peace Prize 2006', '"for their efforts to create economic and social development from below"', '1/2', 810, 'Organization', 'Grameen Bank', None, None, None, None, None, None, None, None, None, None),
#  (800, 2007, 'Peace', 'The Nobel Peace Prize 2007', '"for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change"', '1/2', 818, 'Organization', 'Intergovernmental Panel on Climate Change (IPCC)', None, None, None, None, None, None, None, None, None, None),
#  (816, 2009, 'Chemistry', 'The Nobel Prize in Chemistry 2009', '"for studies of the structure and function of the ribosome"', '1/3', 841, 'Individual', 'Venkatraman Ramakrishnan', None, 'Chidambaram, Tamil Nadu', 'India', 'Male', 'MRC Laboratory of Molecular Biology', 'Cambridge', 'United Kingdom', None, None, None),
#  (837, 2010, 'Peace', 'The Nobel Peace Prize 2010', '"for his long and non-violent struggle for fundamental human rights in China"', '1/1', 855, 'Individual', 'Liu Xiaobo', '1955-12-28', None, 'China', 'Male', None, None, None, None, None, None),
#  (850, 2011, 'Physics', 'The Nobel Prize in Physics 2011', '"for the discovery of the accelerating expansion of the Universe through observations of distant supernovae"', '1/2', 864, 'Individual', 'Saul Perlmutter', None, 'Champaign-Urbana, IL', 'United States of America', 'Male', 'Lawrence Berkeley National Laboratory', 'Berkeley, CA', 'United States of America', None, None, None),
#  (860, 2012, 'Peace', 'The Nobel Peace Prize 2012', '"for over six decades contributed to the advancement of peace and reconciliation, democracy and human rights in Europe"', '1/1', 881, 'Organization', 'European Union (EU)', None, None, None, None, None, None, None, None, None, None),
#  (873, 2013, 'Peace', 'The Nobel Peace Prize 2013', '"for its extensive efforts to eliminate chemical weapons"', '1/1', 893, 'Organization', 'Organisation for the Prohibition of Chemical Weapons (OPCW)', None, None, None, None, None, None, None, None, None, None),
#  (897, 2015, 'Peace', 'The Nobel Peace Prize 2015', '"for its decisive contribution to the building of a pluralistic democracy in Tunisia in the wake of the Jasmine Revolution of 2011"', '1/1', 925, 'Organization', 'National Dialogue Quartet', None, None, None, None, None, None, None, None, None, None),
#  (921, 2017, 'Peace', 'The Nobel Peace Prize 2017', '"for its work to draw attention to the catastrophic humanitarian consequences of any use of nuclear weapons and for its ground-breaking efforts to achieve a treaty-based prohibition of such weapons"', '1/1', 948, 'Organization', 'International Campaign to Abolish Nuclear Weapons', None, None, None, None, None, None, None, None, None, None),
#  (943, 2019, 'Chemistry', 'The Nobel Prize in Chemistry 2019', '"for the development of lithium-ion batteries"', '1/3', 977, 'Individual', 'M. Stanley Whittingham', '1941-12-22', None, 'United Kingdom', 'Male', 'Binghamton University State University of New York', 'New York, NY', 'United States of America', None, None, None),
#  (951, 2020, 'Medicine', 'The Nobel Prize in Physiology or Medicine 2020', '"for the discovery of Hepatitis C virus"', '1/3', 986, 'Individual', 'Michael Houghton', '1949-00-00', None, 'United Kingdom', 'Male', 'University of Alberta', 'Edmonton', 'Canada', None, None, None),
#  (959, 2020, 'Peace', 'The Nobel Peace Prize 2020', '"for its efforts to combat hunger for its contribution to bettering conditions for peace in conflict-affected areas and for acting as a driving force in efforts to prevent the use of hunger as a weapon of war and conflict"', '1/1', 994, 'Organization', 'World Food Programme', None, None, None, None, None, None, None, None, None, None),
#  (969, 2021, 'Literature', 'The Nobel Prize in Literature 2021', '"for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents"', '1/1', 1004, 'Individual', 'Abdulrazak Gurnah', '1948-00-00', None, None, 'Male', None, None, None, None, None, None),
#  (984, 2022, 'Peace', 'The Nobel Peace Prize 2022', '"The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protec ... (77 characters truncated) ...  document war crimes human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy."', '1/3', 1019, 'Organization', 'Memorial', None, None, None, None, None, None, None, None, None, None),
#  (985, 2022, 'Peace', 'The Nobel Peace Prize 2022', '"The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protec ... (77 characters truncated) ...  document war crimes human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy."', '1/3', 1020, 'Organization', 'Center for Civil Liberties', None, None, None, None, None, None, None, None, None, None),
#  (996, 2023, 'Chemistry', 'The Nobel Prize in Chemistry 2023', '"for the discovery and synthesis of quantum dots"', '1/3', 1031, 'Individual', 'Aleksey Yekimov', '1945-00-00', None, 'USSR (now Russia)', 'Male', 'Nanocrystals Technology Inc.', 'New York, NY', 'United States of America', None, None, None)]

# %%
# %%sql
# /* Mostly, the laureate_type is organization.
# In addition, organizations seems to be missing values
# at organization_name, organization_city, and organization_country column.
# Lets check if any organization has a birth_date. */
#
# SELECT *
# FROM nobel
# WHERE laureate_type LIKE 'Org%' AND birth_date IS NOT NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(435, 1973, 'Peace', 'The Nobel Peace Prize 1973', None, '1/2', 531, 'Organization', 'Le Duc Tho', '1911-10-14', 'Nam Ha province', 'Vietnam', 'Male', None, None, None, '1990-10-13', 'Hanoi', 'Vietnam'),
#  (501, 1979, 'Peace', 'The Nobel Peace Prize 1979', None, '1/1', 540, 'Organization', 'Mother Teresa', '1910-08-26', 'Uskup (Skopje)', 'Ottoman Empire (Republic of Macedonia)', 'Female', None, None, None, '1997-09-05', 'Calcutta', 'India'),
#  (598, 1989, 'Peace', 'The Nobel Peace Prize 1989', None, '1/1', 551, 'Organization', 'The 14th Dalai Lama (Tenzin Gyatso)', '1935-07-06', 'Taktser', "Tibet (People's Republic of China)", 'Male', None, None, None, None, None, None),
#  (618, 1991, 'Peace', 'The Nobel Peace Prize 1991', '"for her non-violent struggle for democracy and human rights"', '1/1', 553, 'Organization', 'Aung San Suu Kyi', '1945-06-19', 'Rangoon (Yangon)', 'Burma (Myanmar)', 'Female', None, None, None, None, None, None)]

# %%
# %%sql
# /* Now, we can look which individuals are missing birth_date */
#
# SELECT *
# FROM nobel
# WHERE laureate_type LIKE 'Ind%' AND birth_date IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(816, 2009, 'Chemistry', 'The Nobel Prize in Chemistry 2009', '"for studies of the structure and function of the ribosome"', '1/3', 841, 'Individual', 'Venkatraman Ramakrishnan', None, 'Chidambaram, Tamil Nadu', 'India', 'Male', 'MRC Laboratory of Molecular Biology', 'Cambridge', 'United Kingdom', None, None, None),
#  (850, 2011, 'Physics', 'The Nobel Prize in Physics 2011', '"for the discovery of the accelerating expansion of the Universe through observations of distant supernovae"', '1/2', 864, 'Individual', 'Saul Perlmutter', None, 'Champaign-Urbana, IL', 'United States of America', 'Male', 'Lawrence Berkeley National Laboratory', 'Berkeley, CA', 'United States of America', None, None, None)]

# %%
# %%sql
# /* check columns with missing data to find out if there is any reason for that
# or if they have something in common. Finally, lets check columns related to
# organization_name, _city, and _country where was 735 records out of 1000. */
#
# SELECT *
# FROM nobel
# WHERE organization_name IS NULL
# OR organization_city IS NULL
# OR organization_country IS NULL;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(1, 1901, 'Literature', 'The Nobel Prize in Literature 1901', '"in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect"', '1/1', 569, 'Individual', 'Sully Prudhomme', '1839-03-16', 'Paris', 'France', 'Male', None, None, None, '1907-09-07', 'Châtenay', 'France'),
#  (3, 1901, 'Peace', 'The Nobel Peace Prize 1901', None, '1/2', 462, 'Individual', 'Jean Henry Dunant', '1828-05-08', 'Geneva', 'Switzerland', 'Male', None, None, None, '1910-10-30', 'Heiden', 'Switzerland'),
#  (4, 1901, 'Peace', 'The Nobel Peace Prize 1901', None, '1/2', 463, 'Individual', 'Frédéric Passy', '1822-05-20', 'Paris', 'France', 'Male', None, None, None, '1912-06-12', 'Paris', 'France'),
#  (7, 1902, 'Literature', 'The Nobel Prize in Literature 1902', '"the greatest living master of the art of historical writing, with special reference to his monumental work, <I>A history of Rome</I>"', '1/1', 571, 'Individual', 'Christian Matthias Theodor Mommsen', '1817-11-30', 'Garding', 'Schleswig (Germany)', 'Male', None, None, None, '1903-11-01', 'Charlottenburg', 'Germany'),
#  (9, 1902, 'Peace', 'The Nobel Peace Prize 1902', None, '1/2', 464, 'Individual', 'Élie Ducommun', '1833-02-19', 'Geneva', 'Switzerland', 'Male', None, None, None, '1906-12-07', 'Bern', 'Switzerland'),
#  (10, 1902, 'Peace', 'The Nobel Peace Prize 1902', None, '1/2', 465, 'Individual', 'Charles Albert Gobat', '1843-05-21', 'Tramelan', 'Switzerland', 'Male', None, None, None, '1914-03-16', 'Bern', 'Switzerland'),
#  (14, 1903, 'Literature', 'The Nobel Prize in Literature 1903', '"as a tribute to his noble, magnificent and versatile poetry, which has always been distinguished by both the freshness of its inspiration and the rare purity of its spirit"', '1/1', 572, 'Individual', 'Bjørnstjerne Martinus Bjørnson', '1832-12-08', 'Kvikne', 'Norway', 'Male', None, None, None, '1910-04-26', 'Paris', 'France'),
#  (16, 1903, 'Peace', 'The Nobel Peace Prize 1903', None, '1/1', 466, 'Individual', 'William Randal Cremer', '1828-03-18', 'Fareham', 'United Kingdom', 'Male', None, None, None, '1908-07-22', 'London', 'United Kingdom'),
#  (19, 1903, 'Physics', 'The Nobel Prize in Physics 1903', '"in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"', '1/4', 6, 'Individual', 'Marie Curie, née Sklodowska', '1867-11-07', 'Warsaw', 'Russian Empire (Poland)', 'Female', None, None, None, '1934-07-04', 'Sallanches', 'France'),
#  (21, 1904, 'Literature', 'The Nobel Prize in Literature 1904', '"in recognition of the fresh originality and true inspiration of his poetic production, which faithfully reflects the natural scenery and native spirit of his people, and, in addition, his significant work as a Proven&ccedil;al philologist"', '1/2', 573, 'Individual', 'Frédéric Mistral', '1830-09-08', 'Maillane', 'France', 'Male', None, None, None, '1914-03-25', 'Maillane', 'France'),
#  (22, 1904, 'Literature', 'The Nobel Prize in Literature 1904', '"in recognition of the numerous and brilliant compositions which, in an individual and original manner, have revived the great traditions of the Spanish drama"', '1/2', 574, 'Individual', 'José Echegaray y Eizaguirre', '1832-04-19', 'Madrid', 'Spain', 'Male', None, None, None, '1916-09-04', 'Madrid', 'Spain'),
#  (24, 1904, 'Peace', 'The Nobel Peace Prize 1904', None, '1/1', 467, 'Organization', 'Institut de droit international (Institute of International Law)', None, None, None, None, None, None, None, None, None, None),
#  (27, 1905, 'Literature', 'The Nobel Prize in Literature 1905', '"because of his outstanding merits as an epic writer"', '1/1', 575, 'Individual', 'Henryk Sienkiewicz', '1846-05-05', 'Wola Okrzejska', 'Poland', 'Male', None, None, None, '1916-11-15', 'Vevey', 'Switzerland'),
#  (29, 1905, 'Peace', 'The Nobel Peace Prize 1905', None, '1/1', 468, 'Individual', 'Baroness Bertha Sophie Felicita von Suttner, née Countess Kinsky von Chinic und Tettau', '1843-06-09', 'Prague', 'Austrian Empire (Czech Republic)', 'Female', None, None, None, '1914-06-21', 'Vienna', 'Austria'),
#  (32, 1906, 'Literature', 'The Nobel Prize in Literature 1906', '"not only in consideration of his deep learning and critical research, but above all as a tribute to the creative energy, freshness of style, and lyrical force which characterize his poetic masterpieces"', '1/1', 576, 'Individual', 'Giosuè Carducci', '1835-07-27', 'Val di Castello', 'Tuscany (Italy)', 'Male', None, None, None, '1907-02-16', 'Bologna', 'Italy'),
#  (35, 1906, 'Peace', 'The Nobel Peace Prize 1906', None, '1/1', 470, 'Individual', 'Theodore Roosevelt', '1858-10-27', 'New York, NY', 'United States of America', 'Male', None, None, None, '1919-01-06', 'Oyster Bay, NY', 'United States of America'),
#  (38, 1907, 'Literature', 'The Nobel Prize in Literature 1907', '"in consideration of the power of observation, originality of imagination, virility of ideas and remarkable talent for narration which characterize the creations of this world-famous author"', '1/1', 577, 'Individual', 'Rudyard Kipling', '1865-12-30', 'Bombay', 'British India (India)', 'Male', None, None, None, '1936-01-18', 'London', 'United Kingdom'),
#  (40, 1907, 'Peace', 'The Nobel Peace Prize 1907', None, '1/2', 471, 'Individual', 'Ernesto Teodoro Moneta', '1833-09-20', 'Milan', 'Austrian Empire (Italy)', 'Male', None, None, None, '1918-02-10', 'Milan', 'Italy'),
#  (44, 1908, 'Literature', 'The Nobel Prize in Literature 1908', '"in recognition of his earnest search for truth, his penetrating power of thought, his wide range of vision, and the warmth and strength in presentation with which in his numerous works he has vindicated and developed an idealistic philosophy of life"', '1/1', 578, 'Individual', 'Rudolf Christoph Eucken', '1846-01-05', 'Aurich', 'East Friesland (Germany)', 'Male', None, None, None, '1926-09-14', 'Jena', 'Germany'),
#  (47, 1908, 'Peace', 'The Nobel Peace Prize 1908', None, '1/2', 473, 'Individual', 'Klas Pontus Arnoldson', '1844-10-27', 'Gothenburg', 'Sweden', 'Male', None, None, None, '1916-02-20', 'Stockholm', 'Sweden'),
#  (48, 1908, 'Peace', 'The Nobel Peace Prize 1908', None, '1/2', 474, 'Individual', 'Fredrik Bajer', '1837-04-21', 'Næstved', 'Denmark', 'Male', None, None, None, '1922-01-22', 'Copenhagen', 'Denmark'),
#  (51, 1909, 'Literature', 'The Nobel Prize in Literature 1909', '"in appreciation of the lofty idealism, vivid imagination and spiritual perception that characterize her writings"', '1/1', 579, 'Individual', 'Selma Ottilia Lovisa Lagerlöf', '1858-11-20', 'Mårbacka', 'Sweden', 'Female', None, None, None, '1940-03-16', 'Mårbacka', 'Sweden'),
#  (53, 1909, 'Peace', 'The Nobel Peace Prize 1909', None, '1/2', 475, 'Individual', 'Auguste Marie François Beernaert', '1829-07-26', 'Ostend', 'Belgium', 'Male', None, None, None, '1912-10-06', 'Lucerne', 'Switzerland'),
#  (54, 1909, 'Peace', 'The Nobel Peace Prize 1909', None, '1/2', 476, 'Individual', "Paul Henri Benjamin Balluet d'Estournelles de Constant, Baron de Constant de Rebecque", '1852-11-22', 'La Flèche', 'France', 'Male', None, None, None, '1924-05-15', 'Paris', 'France'),
#  (58, 1910, 'Literature', 'The Nobel Prize in Literature 1910', '"as a tribute to the consummate artistry, permeated with idealism, which he has demonstrated during his long productive career as a lyric poet, dramatist, novelist and writer of world-renowned short stories"', '1/1', 580, 'Individual', 'Paul Johann Ludwig Heyse', '1830-03-15', 'Berlin', 'Prussia (Germany)', 'Male', None, None, None, '1914-04-02', 'Munich', 'Germany'),
#  (60, 1910, 'Peace', 'The Nobel Peace Prize 1910', None, '1/1', 477, 'Organization', 'Bureau international permanent de la Paix (Permanent International Peace Bureau)', None, None, None, None, None, None, None, None, None, None),
#  (63, 1911, 'Literature', 'The Nobel Prize in Literature 1911', '"in appreciation of his many-sided literary activities, and especially of his dramatic works, which are distinguished by a wealth of imagination and  ... (46 characters truncated) ...  the guise of a fairy tale, a deep inspiration, while in a mysterious way they appeal to the readers\' own feelings and stimulate their imaginations"', '1/1', 581, 'Individual', 'Count Maurice (Mooris) Polidore Marie Bernhard Maeterlinck', '1862-08-29', 'Ghent', 'Belgium', 'Male', None, None, None, '1949-05-06', 'Nice', 'France'),
#  (65, 1911, 'Peace', 'The Nobel Peace Prize 1911', None, '1/2', 478, 'Individual', 'Tobias Michael Carel Asser', '1838-04-28', 'Amsterdam', 'Netherlands', 'Male', None, None, None, '1913-07-29', 'the Hague', 'Netherlands'),
#  (66, 1911, 'Peace', 'The Nobel Peace Prize 1911', None, '1/2', 479, 'Individual', 'Alfred Hermann Fried', '1864-11-11', 'Vienna', 'Austria', 'Male', None, None, None, '1921-05-05', 'Vienna', 'Austria'),
#  (70, 1912, 'Literature', 'The Nobel Prize in Literature 1912', '"primarily in recognition of his fruitful, varied and outstanding production in the realm of dramatic art"', '1/1', 582, 'Individual', 'Gerhart Johann Robert Hauptmann', '1862-11-15', 'Bad Salzbrunn', 'Prussia (Germany)', 'Male', None, None, None, '1946-06-06', 'Agnetendorf (Jagniatków)', 'Germany (Poland)'),
#  (72, 1912, 'Peace', 'The Nobel Peace Prize 1912', None, '1/1', 480, 'Individual', 'Elihu Root', '1845-02-15', 'Clinton, NY', 'United States of America', 'Male', None, None, None, '1937-02-07', 'New York, NY', 'United States of America'),
#  (75, 1913, 'Literature', 'The Nobel Prize in Literature 1913', '"because of his profoundly sensitive, fresh and beautiful verse, by which, with consummate skill, he has made his poetic thought, expressed in his own English words, a part of the literature of the West"', '1/1', 583, 'Individual', 'Rabindranath Tagore', '1861-05-07', 'Calcutta', 'India', 'Male', None, None, None, '1941-08-07', 'Calcutta', 'India'),
#  (77, 1913, 'Peace', 'The Nobel Peace Prize 1913', None, '1/1', 481, 'Individual', 'Henri La Fontaine', '1854-04-22', 'Brussels', 'Belgium', 'Male', None, None, None, '1943-05-14', 'Brussels', 'Belgium'),
#  (83, 1915, 'Literature', 'The Nobel Prize in Literature 1915', '"as a tribute to the lofty idealism of his literary production and to the sympathy and love of truth with which he has described different types of human beings"', '1/1', 584, 'Individual', 'Romain Rolland', '1866-01-29', 'Clamecy', 'France', 'Male', None, None, None, '1944-12-30', 'Vézelay', 'France'),
#  (86, 1916, 'Literature', 'The Nobel Prize in Literature 1916', '"in recognition of his significance as the leading representative of a new era in our literature"', '1/1', 585, 'Individual', 'Carl Gustaf Verner von Heidenstam', '1859-07-06', 'Olshammar', 'Sweden', 'Male', None, None, None, '1940-05-20', 'Övralid', 'Sweden'),
#  (87, 1917, 'Literature', 'The Nobel Prize in Literature 1917', '"for his varied and rich poetry, which is inspired by lofty ideals"', '1/2', 586, 'Individual', 'Karl Adolph Gjellerup', '1857-06-02', 'Roholte', 'Denmark', 'Male', None, None, None, '1919-10-11', 'Klotzsche', 'Germany'),
#  (88, 1917, 'Literature', 'The Nobel Prize in Literature 1917', '"for his authentic descriptions of present-day life in Denmark"', '1/2', 587, 'Individual', 'Henrik Pontoppidan', '1857-07-24', 'Fredericia', 'Denmark', 'Male', None, None, None, '1943-08-21', 'Ordrup', 'Denmark'),
#  (89, 1917, 'Peace', 'The Nobel Peace Prize 1917', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (93, 1919, 'Literature', 'The Nobel Prize in Literature 1919', '"in special appreciation of his epic, <I>Olympian Spring</I>"', '1/1', 588, 'Individual', 'Carl Friedrich Georg Spitteler', '1845-04-24', 'Liestal', 'Switzerland', 'Male', None, None, None, '1924-12-29', 'Lucerne', 'Switzerland'),
#  (95, 1919, 'Peace', 'The Nobel Peace Prize 1919', None, '1/1', 483, 'Individual', 'Thomas Woodrow Wilson', '1856-12-28', 'Staunton, VA', 'United States of America', 'Male', None, None, None, '1924-02-03', 'Washington, DC', 'United States of America'),
#  (98, 1920, 'Literature', 'The Nobel Prize in Literature 1920', '"for his monumental work, <I>Growth of the Soil</I>"', '1/1', 589, 'Individual', 'Knut Pedersen Hamsun', '1859-08-04', 'Lom', 'Norway', 'Male', None, None, None, '1952-02-19', 'Grimstad', 'Norway'),
#  (100, 1920, 'Peace', 'The Nobel Peace Prize 1920', None, '1/1', 484, 'Individual', 'Léon Victor Auguste Bourgeois', '1851-05-21', 'Paris', 'France', 'Male', None, None, None, '1925-09-29', 'Épernay', 'France'),
#  (103, 1921, 'Literature', 'The Nobel Prize in Literature 1921', '"in recognition of his brilliant literary achievements, characterized as they are by a nobility of style, a profound human sympathy, grace, and a true Gallic temperament"', '1/1', 590, 'Individual', 'Anatole France', '1844-04-16', 'Paris', 'France', 'Male', None, None, None, '1924-10-12', 'Saint-Cyr-sur-Loire', 'France'),
#  (104, 1921, 'Peace', 'The Nobel Peace Prize 1921', None, '1/2', 485, 'Individual', 'Karl Hjalmar Branting', '1860-11-23', 'Stockholm', 'Sweden', 'Male', None, None, None, '1925-02-24', 'Stockholm', 'Sweden'),
#  (105, 1921, 'Peace', 'The Nobel Peace Prize 1921', None, '1/2', 486, 'Individual', 'Christian Lous Lange', '1869-09-17', 'Stavanger', 'Norway', 'Male', None, None, None, '1938-12-11', 'Oslo', 'Norway'),
#  (108, 1922, 'Literature', 'The Nobel Prize in Literature 1922', '"for the happy manner in which he has continued the illustrious traditions of the Spanish drama"', '1/1', 592, 'Individual', 'Jacinto Benavente', '1866-08-12', 'Madrid', 'Spain', 'Male', None, None, None, '1954-07-14', 'Madrid', 'Spain'),
#  (111, 1922, 'Peace', 'The Nobel Peace Prize 1922', None, '1/1', 487, 'Individual', 'Fridtjof Nansen', '1861-10-10', 'Kristiania (Oslo)', 'Norway', 'Male', None, None, None, '1930-05-13', 'Oslo', 'Norway'),
#  (114, 1923, 'Literature', 'The Nobel Prize in Literature 1923', '"for his always inspired poetry, which in a highly artistic form gives expression to the spirit of a whole nation"', '1/1', 593, 'Individual', 'William Butler Yeats', '1865-06-13', 'Dublin', 'Ireland', 'Male', None, None, None, '1939-01-28', 'Roquebrune-Cap-Martin', 'France'),
#  (118, 1924, 'Literature', 'The Nobel Prize in Literature 1924', '"for his great national epic, <I>The Peasants</I>"', '1/1', 594, 'Individual', 'Wladyslaw Stanislaw Reymont', '1867-05-07', 'Kobiele Wielkie', 'Russian Empire (Poland)', 'Male', None, None, None, '1925-12-05', 'Warsaw', 'Poland'),
#  (122, 1925, 'Literature', 'The Nobel Prize in Literature 1925', '"for his work which is marked by both idealism and humanity, its stimulating satire often being infused with a singular poetic beauty"', '1/1', 596, 'Individual', 'George Bernard Shaw', '1856-07-26', 'Dublin', 'Ireland', 'Male', None, None, None, '1950-11-02', 'Ayot St. Lawrence', 'United Kingdom'),
#  (123, 1925, 'Peace', 'The Nobel Peace Prize 1925', None, '1/2', 488, 'Individual', 'Sir Austen Chamberlain', '1863-10-16', 'Birmingham', 'United Kingdom', 'Male', None, None, None, '1937-03-16', 'London', 'United Kingdom'),
#  (124, 1925, 'Peace', 'The Nobel Peace Prize 1925', None, '1/2', 489, 'Individual', 'Charles Gates Dawes', '1865-08-27', 'Marietta, OH', 'United States of America', 'Male', None, None, None, '1951-04-23', 'Evanston, IL', 'United States of America'),
#  (128, 1926, 'Literature', 'The Nobel Prize in Literature 1926', '"for her idealistically inspired writings which with plastic clarity picture the life on her native island and with depth and sympathy deal with human problems in general"', '1/1', 597, 'Individual', 'Grazia Deledda', '1871-09-27', 'Nuoro, Sardinia', 'Italy', 'Female', None, None, None, '1936-08-15', 'Rome', 'Italy'),
#  (130, 1926, 'Peace', 'The Nobel Peace Prize 1926', None, '1/2', 490, 'Individual', 'Aristide Briand', '1862-03-28', 'Nantes', 'France', 'Male', None, None, None, '1932-03-07', 'Paris', 'France'),
#  (131, 1926, 'Peace', 'The Nobel Peace Prize 1926', None, '1/2', 491, 'Individual', 'Gustav Stresemann', '1878-05-10', 'Berlin', 'Germany', 'Male', None, None, None, '1929-10-03', 'Berlin', 'Germany'),
#  (134, 1927, 'Literature', 'The Nobel Prize in Literature 1927', '"in recognition of his rich and vitalizing ideas and the brilliant skill with which they have been presented"', '1/1', 600, 'Individual', 'Henri Bergson', '1859-10-18', 'Paris', 'France', 'Male', None, None, None, '1941-01-04', 'Paris', 'France'),
#  (136, 1927, 'Peace', 'The Nobel Peace Prize 1927', None, '1/2', 492, 'Individual', 'Ferdinand Buisson', '1841-12-20', 'Paris', 'France', 'Male', None, None, None, '1932-02-16', 'Thieuloy-Saint-Antoine', 'France'),
#  (137, 1927, 'Peace', 'The Nobel Peace Prize 1927', None, '1/2', 493, 'Individual', 'Ludwig Quidde', '1858-03-23', 'Bremen', 'Germany', 'Male', None, None, None, '1941-03-04', 'Geneva', 'Switzerland'),
#  (141, 1928, 'Literature', 'The Nobel Prize in Literature 1928', '"principally for her powerful descriptions of Northern life during the Middle Ages"', '1/1', 601, 'Individual', 'Sigrid Undset', '1882-05-20', 'Kalundborg', 'Denmark', 'Female', None, None, None, '1949-06-10', 'Lillehammer', 'Norway'),
#  (142, 1928, 'Medicine', 'The Nobel Prize in Physiology or Medicine 1928', '"for his work on typhus"', '1/1', 318, 'Individual', 'Charles Jules Henri Nicolle', '1866-09-21', 'Rouen', 'France', 'Male', 'Institut Pasteur', 'Tunis', None, '1936-02-28', 'Tunis', 'Tunisia'),
#  (146, 1929, 'Literature', 'The Nobel Prize in Literature 1929', '"principally for his great novel, <I>Buddenbrooks</I>, which has won steadily increased recognition as one of the classic works of contemporary literature"', '1/1', 602, 'Individual', 'Thomas Mann', '1875-06-06', 'Lübeck', 'Germany', 'Male', None, None, None, '1955-08-12', 'Zurich', 'Switzerland'),
#  (149, 1929, 'Peace', 'The Nobel Peace Prize 1929', None, '1/1', 494, 'Individual', 'Frank Billings Kellogg', '1856-12-22', 'Potsdam, NY', 'United States of America', 'Male', None, None, None, '1937-12-21', 'St. Paul, MN', 'United States of America'),
#  (152, 1930, 'Literature', 'The Nobel Prize in Literature 1930', '"for his vigorous and graphic art of description and his ability to create, with wit and humour, new types of characters"', '1/1', 603, 'Individual', 'Sinclair Lewis', '1885-02-07', 'Sauk Centre, MN', 'United States of America', 'Male', None, None, None, '1951-01-10', 'Rome', 'Italy'),
#  (154, 1930, 'Peace', 'The Nobel Peace Prize 1930', None, '1/1', 495, 'Individual', 'Lars Olof Jonathan (Nathan) Söderblom', '1866-01-15', 'Trönö', 'Sweden', 'Male', None, None, None, '1931-07-12', 'Uppsala', 'Sweden'),
#  (158, 1931, 'Literature', 'The Nobel Prize in Literature 1931', '"The poetry of Erik Axel Karlfeldt"', '1/1', 604, 'Individual', 'Erik Axel Karlfeldt', '1864-07-20', 'Karlbo', 'Sweden', 'Male', None, None, None, '1931-04-08', 'Stockholm', 'Sweden'),
#  (160, 1931, 'Peace', 'The Nobel Peace Prize 1931', None, '1/2', 496, 'Individual', 'Jane Addams', '1860-09-06', 'Cedarville, IL', 'United States of America', 'Female', None, None, None, '1935-05-21', 'Chicago, IL', 'United States of America'),
#  (163, 1932, 'Literature', 'The Nobel Prize in Literature 1932', '"for his distinguished art of narration which takes its highest form in <I>The Forsyte Saga</I>"', '1/1', 605, 'Individual', 'John Galsworthy', '1867-08-14', 'Kingston Hill', 'United Kingdom', 'Male', None, None, None, '1933-01-31', 'London', 'United Kingdom'),
#  (167, 1933, 'Literature', 'The Nobel Prize in Literature 1933', '"for the strict artistry with which he has carried on the classical Russian traditions in prose writing"', '1/1', 606, 'Individual', 'Ivan Alekseyevich Bunin', '1870-10-22', 'Voronezh', 'Russia', 'Male', None, None, None, '1953-11-08', 'Paris', 'France'),
#  (169, 1933, 'Peace', 'The Nobel Peace Prize 1933', None, '1/1', 498, 'Individual', 'Sir Norman Angell (Ralph Lane)', '1872-12-26', 'Holbeach', 'United Kingdom', 'Male', None, None, None, '1967-10-07', 'Croydon', 'United Kingdom'),
#  (173, 1934, 'Literature', 'The Nobel Prize in Literature 1934', '"for his bold and ingenious revival of dramatic and scenic art"', '1/1', 607, 'Individual', 'Luigi Pirandello', '1867-06-28', 'Agrigento, Sicily', 'Italy', 'Male', None, None, None, '1936-12-10', 'Rome', 'Italy'),
#  (177, 1934, 'Peace', 'The Nobel Peace Prize 1934', None, '1/1', 499, 'Individual', 'Arthur Henderson', '1863-09-13', 'Glasgow', 'Scotland', 'Male', None, None, None, '1935-10-20', 'London', 'United Kingdom'),
#  (181, 1935, 'Peace', 'The Nobel Peace Prize 1935', None, '1/1', 500, 'Individual', 'Carl von Ossietzky', '1889-10-03', 'Hamburg', 'Germany', 'Male', None, None, None, '1938-05-04', 'Berlin', 'Germany'),
#  (184, 1936, 'Literature', 'The Nobel Prize in Literature 1936', '"for the power, honesty and deep-felt emotions of his dramatic works, which embody an original concept of tragedy"', '1/1', 608, 'Individual', "Eugene Gladstone O'Neill", '1888-10-16', 'New York, NY', 'United States of America', 'Male', None, None, None, '1953-11-27', 'Boston, MA', 'United States of America'),
#  (187, 1936, 'Peace', 'The Nobel Peace Prize 1936', None, '1/1', 501, 'Individual', 'Carlos Saavedra Lamas', '1878-11-01', 'Buenos Aires', 'Argentina', 'Male', None, None, None, '1959-05-05', 'Buenos Aires', 'Argentina'),
#  (192, 1937, 'Literature', 'The Nobel Prize in Literature 1937', '"for the artistic power and truth with which he has depicted human conflict as well as some fundamental aspects of contemporary life in his novel-cycle <I>Les Thibault</I>"', '1/1', 609, 'Individual', 'Roger Martin du Gard', '1881-03-23', 'Neuilly-sur-Seine', 'France', 'Male', None, None, None, '1958-08-22', 'Bellême', 'France'),
#  (194, 1937, 'Peace', 'The Nobel Peace Prize 1937', None, '1/1', 502, 'Individual', 'Cecil of Chelwood, Viscount (Lord Edgar Algernon Robert Gascoyne Cecil)', '1864-09-14', 'London', 'United Kingdom', 'Male', None, None, None, '1958-11-24', 'Tunbridge Wells', 'United Kingdom'),
#  (198, 1938, 'Literature', 'The Nobel Prize in Literature 1938', '"for her rich and truly epic descriptions of peasant life in China and for her biographical masterpieces"', '1/1', 610, 'Individual', 'Pearl Buck', '1892-06-26', 'Hillsboro, WV', 'United States of America', 'Female', None, None, None, '1973-03-06', 'Danby, VT', 'United States of America'),
#  (200, 1938, 'Peace', 'The Nobel Peace Prize 1938', None, '1/1', 503, 'Organization', 'Office international Nansen pour les Réfugiés (Nansen International Office for Refugees)', None, None, None, None, None, None, None, None, None, None),
#  (204, 1939, 'Literature', 'The Nobel Prize in Literature 1939', '"for his deep understanding of his country\'s peasantry and the exquisite art with which he has portrayed their way of life and their relationship with Nature"', '1/1', 613, 'Individual', 'Frans Eemil Sillanpää', '1888-09-16', 'Hämeenkyrö', 'Russian Empire (Finland)', 'Male', None, None, None, '1964-06-03', 'Helsinki', 'Finland'),
#  (212, 1944, 'Literature', 'The Nobel Prize in Literature 1944', '"for the rare strength and fertility of his poetic imagination with which is combined an intellectual curiosity of wide scope and a bold, freshly creative style"', '1/1', 614, 'Individual', 'Johannes Vilhelm Jensen', '1873-01-20', 'Farsø', 'Denmark', 'Male', None, None, None, '1950-11-25', 'Copenhagen', 'Denmark'),
#  (215, 1944, 'Peace', 'The Nobel Peace Prize 1944', None, '1/1', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (218, 1945, 'Literature', 'The Nobel Prize in Literature 1945', '"for her lyric poetry which, inspired by powerful emotions, has made her name a symbol of the idealistic aspirations of the entire Latin American world"', '1/1', 615, 'Individual', 'Gabriela Mistral', '1889-04-07', 'Vicuña', 'Chile', 'Female', None, None, None, '1957-01-10', 'Hempstead, NY', 'United States of America'),
#  (222, 1945, 'Peace', 'The Nobel Peace Prize 1945', None, '1/1', 505, 'Individual', 'Cordell Hull', '1871-10-02', 'Olympus, TN', 'United States of America', 'Male', None, None, None, '1955-07-23', 'Bethesda, MD', 'United States of America'),
#  (227, 1946, 'Literature', 'The Nobel Prize in Literature 1946', '"for his inspired writings which, while growing in boldness and penetration, exemplify the classical humanitarian ideals and high qualities of style"', '1/1', 617, 'Individual', 'Hermann Hesse', '1877-07-02', 'Calw', 'Germany', 'Male', None, None, None, '1962-08-09', 'Montagnola', 'Switzerland'),
#  (229, 1946, 'Peace', 'The Nobel Peace Prize 1946', None, '1/2', 506, 'Individual', 'Emily Greene Balch', '1867-01-08', 'Jamaica Plain, MA (Boston)', 'United States of America', 'Female', None, None, None, '1961-01-09', 'Cambridge, MA', 'United States of America'),
#  (230, 1946, 'Peace', 'The Nobel Peace Prize 1946', None, '1/2', 507, 'Individual', 'John Raleigh Mott', '1865-05-25', 'Livingston Manor, NY', 'United States of America', 'Male', None, None, None, '1955-01-31', None, 'United States of America'),
#  (233, 1947, 'Literature', 'The Nobel Prize in Literature 1947', '"for his comprehensive and artistically significant writings, in which human problems and conditions have been presented with a fearless love of truth and keen psychological insight"', '1/1', 618, 'Individual', 'André Paul Guillaume Gide', '1869-11-22', 'Paris', 'France', 'Male', None, None, None, '1951-02-19', 'Paris', 'France'),
#  (237, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 508, 'Organization', 'Friends Service Council (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (238, 1947, 'Peace', 'The Nobel Peace Prize 1947', None, '1/2', 509, 'Organization', 'American Friends Service Committee (The Quakers)', None, None, None, None, None, None, None, None, None, None),
#  (241, 1948, 'Literature', 'The Nobel Prize in Literature 1948', '"for his outstanding, pioneer contribution to present-day poetry"', '1/1', 619, 'Individual', 'Thomas Stearns Eliot', '1888-09-26', 'St. Louis, MO', 'United States of America', 'Male', None, None, None, '1965-01-04', 'London', 'United Kingdom'),
#  (245, 1949, 'Literature', 'The Nobel Prize in Literature 1949', '"for his powerful and artistically unique contribution to the modern American novel"', '1/1', 620, 'Individual', 'William Faulkner', '1897-09-25', 'New Albany, MS', 'United States of America', 'Male', None, None, None, '1962-07-06', 'Byhalia, MS', 'United States of America'),
#  (248, 1949, 'Peace', 'The Nobel Peace Prize 1949', None, '1/1', 510, 'Individual', 'Lord (John) Boyd Orr of Brechin', '1880-09-23', 'Kilmaurs', 'Scotland', 'Male', None, None, None, '1971-06-25', 'Edzell', 'Scotland'),
#  (252, 1950, 'Literature', 'The Nobel Prize in Literature 1950', '"in recognition of his varied and significant writings in which he champions humanitarian ideals and freedom of thought"', '1/1', 621, 'Individual', 'Earl (Bertrand Arthur William) Russell', '1872-05-18', 'Trelleck', 'United Kingdom', 'Male', None, None, None, '1970-02-02', 'Penrhyndeudraeth', 'United Kingdom'),
#  (260, 1951, 'Literature', 'The Nobel Prize in Literature 1951', '"for the artistic vigour and true independence of mind with which he endeavours in his poetry to find answers to the eternal questions confronting mankind"', '1/1', 622, 'Individual', 'Pär Fabian Lagerkvist', '1891-05-23', 'Växjö', 'Sweden', 'Male', None, None, None, '1974-07-11', 'Stockholm', 'Sweden'),
#  (262, 1951, 'Peace', 'The Nobel Peace Prize 1951', None, '1/1', 512, 'Individual', 'Léon Jouhaux', '1879-07-01', 'Paris', 'France', 'Male', None, None, None, '1954-04-28', 'Paris', 'France'),
#  (267, 1952, 'Literature', 'The Nobel Prize in Literature 1952', '"for the deep spiritual insight and the artistic intensity with which he has in his novels penetrated the drama of human life"', '1/1', 623, 'Individual', 'François Mauriac', '1885-10-11', 'Bordeaux', 'France', 'Male', None, None, None, '1970-09-01', 'Paris', 'France'),
#  (269, 1952, 'Peace', 'The Nobel Peace Prize 1952', None, '1/1', 513, 'Individual', 'Albert Schweitzer', '1875-01-14', 'Kaysersberg', 'Germany (France)', 'Male', None, None, None, '1965-09-04', 'Lambaréné', 'Gabon'),
#  (273, 1953, 'Literature', 'The Nobel Prize in Literature 1953', '"for his mastery of historical and biographical description as well as for brilliant oratory in defending exalted human values"', '1/1', 624, 'Individual', 'Sir Winston Leonard Spencer Churchill', '1874-11-30', 'Woodstock', 'United Kingdom', 'Male', None, None, None, '1965-01-24', 'London', 'United Kingdom'),
#  (276, 1953, 'Peace', 'The Nobel Peace Prize 1953', None, '1/1', 514, 'Individual', 'George Catlett Marshall', '1880-12-31', 'Uniontown, PA', 'United States of America', 'Male', None, None, None, '1959-10-16', 'Washington, DC', 'United States of America'),
#  (279, 1954, 'Literature', 'The Nobel Prize in Literature 1954', '"for his mastery of the art of narrative, most recently demonstrated in <I>The Old Man and the Sea,</I> and for the influence that he has exerted on contemporary style"', '1/1', 625, 'Individual', 'Ernest Miller Hemingway', '1899-07-21', 'Oak Park, IL', 'United States of America', 'Male', None, None, None, '1961-07-02', 'Ketchum, ID', 'United States of America'),
#  (283, 1954, 'Peace', 'The Nobel Peace Prize 1954', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (287, 1955, 'Literature', 'The Nobel Prize in Literature 1955', '"for his vivid epic power which has renewed the great narrative art of Iceland"', '1/1', 626, 'Individual', 'Halldór Kiljan Laxness', '1902-04-23', 'Reykjavik', 'Iceland', 'Male', None, None, None, '1998-02-08', 'Reykjavik', 'Iceland'),
#  (293, 1956, 'Literature', 'The Nobel Prize in Literature 1956', '"for his lyrical poetry, which in Spanish language constitutes an example of high spirit and artistical purity"', '1/1', 627, 'Individual', 'Juan Ramón Jiménez', '1881-12-24', 'Moguer', 'Spain', 'Male', None, None, None, '1958-05-29', 'San Juan', 'Puerto Rico'),
#  (301, 1957, 'Literature', 'The Nobel Prize in Literature 1957', '"for his important literary production, which with clear-sighted earnestness illuminates the problems of the human conscience in our times"', '1/1', 628, 'Individual', 'Albert Camus', '1913-11-07', 'Mondovi', 'French Algeria (Algeria)', 'Male', None, None, None, '1960-01-04', 'Sens', 'France'),
#  (303, 1957, 'Peace', 'The Nobel Peace Prize 1957', None, '1/1', 516, 'Individual', 'Lester Bowles Pearson', '1897-04-23', 'Toronto', 'Canada', 'Male', None, None, None, '1972-12-27', 'Ottawa', 'Canada'),
#  (307, 1958, 'Literature', 'The Nobel Prize in Literature 1958', '"for his important achievement both in contemporary lyrical poetry and in the field of the great Russian epic tradition"', '1/1', 629, 'Individual', 'Boris Leonidovich Pasternak', '1890-02-10', 'Moscow', 'Russia', 'Male', None, None, None, '1960-05-30', 'Peredelkino', 'Russia'),
#  (311, 1958, 'Peace', 'The Nobel Peace Prize 1958', None, '1/1', 517, 'Individual', 'Georges Pire', '1910-02-10', 'Dinant', 'Belgium', 'Male', None, None, None, '1969-01-30', 'Leuven', 'Belgium'),
#  (316, 1959, 'Literature', 'The Nobel Prize in Literature 1959', '"for his lyrical poetry, which with classical fire expresses the tragic experience of life in our own times"', '1/1', 630, 'Individual', 'Salvatore Quasimodo', '1901-08-20', 'Modica', 'Italy', 'Male', None, None, None, '1968-06-14', 'Naples', 'Italy'),
#  (319, 1959, 'Peace', 'The Nobel Peace Prize 1959', None, '1/1', 518, 'Individual', 'Philip J. Noel-Baker', '1889-11-01', 'London', 'United Kingdom', 'Male', None, None, None, '1982-10-08', 'London', 'United Kingdom'),
#  (323, 1960, 'Literature', 'The Nobel Prize in Literature 1960', '"for the soaring flight and the evocative imagery of his poetry which in a visionary fashion reflects the conditions of our time"', '1/1', 631, 'Individual', 'Saint-John Perse', '1887-05-31', 'Pointe-à-Pitre', 'Guadeloupe Island', 'Male', None, None, None, '1975-09-20', "Presqu'île-de-Giens", 'France'),
#  (326, 1960, 'Peace', 'The Nobel Peace Prize 1960', None, '1/1', 519, 'Individual', 'Albert John Lutuli', '1898-01-01', 'Bulawayo', 'Southern Rhodesia (Zimbabwe)', 'Male', None, None, None, '1967-07-21', 'Stanger', 'South Africa'),
#  (329, 1961, 'Literature', 'The Nobel Prize in Literature 1961', '"for the epic force with which he has traced themes and depicted human destinies drawn from the history of his country"', '1/1', 633, 'Individual', 'Ivo Andric', '1892-10-10', 'Dolac', 'Bosnia (Bosnia and Herzegovina)', 'Male', None, None, None, '1975-03-13', 'Belgrade', 'Yugoslavia (Serbia)'),
#  (331, 1961, 'Peace', 'The Nobel Peace Prize 1961', None, '1/1', 520, 'Individual', 'Dag Hjalmar Agne Carl Hammarskjöld', '1905-07-29', 'Jönköping', 'Sweden', 'Male', None, None, None, '1961-09-18', 'Ndola', 'Northern Rhodesia (Zambia)'),
#  (336, 1962, 'Literature', 'The Nobel Prize in Literature 1962', '"for his realistic and imaginative writings, combining as they do sympathetic humour and keen social perception"', '1/1', 634, 'Individual', 'John Steinbeck', '1902-02-27', 'Salinas, CA', 'United States of America', 'Male', None, None, None, '1968-12-20', 'New York, NY', 'United States of America'),
#  (344, 1963, 'Literature', 'The Nobel Prize in Literature 1963', '"for his eminent lyrical writing, inspired by a deep feeling for the Hellenic world of culture"', '1/1', 635, 'Individual', 'Giorgos Seferis', '1900-03-13', 'Smyrna (Izmir)', 'Ottoman Empire (Turkey)', 'Male', None, None, None, '1971-09-20', 'Athens', 'Greece'),
#  (348, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 482, 'Organization', 'Comité international de la Croix Rouge (International Committee of the Red Cross)', None, None, None, None, None, None, None, None, None, None),
#  (349, 1963, 'Peace', 'The Nobel Peace Prize 1963', None, '1/2', 523, 'Organization', 'Ligue des Sociétés de la Croix-Rouge (League of Red Cross Societies)', None, None, None, None, None, None, None, None, None, None),
#  (354, 1964, 'Literature', 'The Nobel Prize in Literature 1964', '"for his work which, rich in ideas and filled with the spirit of freedom and the quest for truth, has exerted a far-reaching influence on our age"', '1/1', 637, 'Individual', 'Jean-Paul Sartre', '1905-06-21', 'Paris', 'France', 'Male', None, None, None, '1980-04-15', 'Paris', 'France'),
#  (357, 1964, 'Peace', 'The Nobel Peace Prize 1964', None, '1/1', 524, 'Individual', 'Martin Luther King Jr.', '1929-01-15', 'Atlanta, GA', 'United States of America', 'Male', None, None, None, '1968-04-04', 'Memphis, TN', 'United States of America'),
#  (362, 1965, 'Literature', 'The Nobel Prize in Literature 1965', '"for the artistic power and integrity with which, in his epic of the Don, he has given expression to a historic phase in the life of the Russian people"', '1/1', 638, 'Individual', 'Mikhail Aleksandrovich Sholokhov', '1905-05-24', 'Veshenskaya', 'Russia', 'Male', None, None, None, '1984-02-21', 'Veshenskaya', 'Union of Soviet Socialist Republics'),
#  (366, 1965, 'Peace', 'The Nobel Peace Prize 1965', None, '1/1', 525, 'Organization', "United Nations Children's Fund (UNICEF)", None, None, None, None, None, None, None, None, None, None),
#  (371, 1966, 'Literature', 'The Nobel Prize in Literature 1966', '"for his profoundly characteristic narrative art with motifs from the life of the Jewish people"', '1/2', 639, 'Individual', 'Shmuel Yosef Agnon', '1888-07-17', 'Buczacz (Buchach)', 'Austria-Hungary (Ukraine)', 'Male', None, None, None, '1970-02-17', 'Rehovot', 'Israel'),
#  (372, 1966, 'Literature', 'The Nobel Prize in Literature 1966', '"for her outstanding lyrical and dramatic writing, which interprets Israel\'s destiny with touching strength"', '1/2', 640, 'Individual', 'Nelly Sachs', '1891-12-10', 'Berlin', 'Germany', 'Female', None, None, None, '1970-05-12', 'Stockholm', 'Sweden'),
#  (379, 1967, 'Literature', 'The Nobel Prize in Literature 1967', '"for his vivid literary achievement, deep-rooted in the national traits and traditions of Indian peoples of Latin America"', '1/1', 641, 'Individual', 'Miguel Angel Asturias', '1899-10-19', 'Guatemala City', 'Guatemala', 'Male', None, None, None, '1974-06-09', 'Madrid', 'Spain'),
#  (385, 1968, 'Literature', 'The Nobel Prize in Literature 1968', '"for his narrative mastery, which with great sensibility expresses the essence of the Japanese mind"', '1/1', 642, 'Individual', 'Yasunari Kawabata', '1899-06-11', 'Osaka', 'Japan', 'Male', None, None, None, '1972-04-16', 'Zushi', 'Japan'),
#  (389, 1968, 'Peace', 'The Nobel Peace Prize 1968', None, '1/1', 526, 'Individual', 'René Cassin', '1887-10-05', 'Bayonne', 'France', 'Male', None, None, None, '1976-02-20', 'Paris', 'France'),
#  (395, 1969, 'Literature', 'The Nobel Prize in Literature 1969', '"for his writing, which - in new forms for the novel and drama - in the destitution of modern man acquires its elevation"', '1/1', 643, 'Individual', 'Samuel Beckett', '1906-04-13', 'Dublin', 'Ireland', 'Male', None, None, None, '1989-12-22', 'Paris', 'France'),
#  (399, 1969, 'Peace', 'The Nobel Peace Prize 1969', None, '1/1', 527, 'Organization', 'International Labour Organization (I.L.O.)', None, None, None, None, None, None, None, None, None, None),
#  (403, 1970, 'Literature', 'The Nobel Prize in Literature 1970', '"for the ethical force with which he has pursued the indispensable traditions of Russian literature"', '1/1', 644, 'Individual', 'Aleksandr Isayevich Solzhenitsyn', '1918-12-11', 'Kislovodsk', 'Russia', 'Male', None, None, None, '2008-08-03', 'Troitse-Lykovo', 'Russia'),
#  (407, 1970, 'Peace', 'The Nobel Peace Prize 1970', None, '1/1', 528, 'Individual', 'Norman E. Borlaug', '1914-03-25', 'Cresco, IA', 'United States of America', 'Male', None, None, None, '2009-09-12', 'Dallas, TX', 'United States of America'),
#  (412, 1971, 'Literature', 'The Nobel Prize in Literature 1971', '"for a poetry that with the action of an elemental force brings alive a continent\'s destiny and dreams"', '1/1', 645, 'Individual', 'Pablo Neruda', '1904-07-12', 'Parral', 'Chile', 'Male', None, None, None, '1973-09-23', 'Santiago', 'Chile'),
#  (414, 1971, 'Peace', 'The Nobel Peace Prize 1971', None, '1/1', 529, 'Individual', 'Willy Brandt', '1913-12-18', 'Lübeck', 'Germany', 'Male', None, None, None, '1992-10-08', 'Unkel', 'Germany'),
#  (421, 1972, 'Literature', 'The Nobel Prize in Literature 1972', '"for his writing which through its combination of a broad perspective on his time and a sensitive skill in characterization has contributed to a renewal of German literature"', '1/1', 647, 'Individual', 'Heinrich Böll', '1917-12-21', 'Cologne', 'Germany', 'Male', None, None, None, '1985-07-16', 'Bornheim-Merten', 'West Germany (Germany)'),
#  (430, 1973, 'Literature', 'The Nobel Prize in Literature 1973', '"for an epic and psychological narrative art which has introduced a new continent into literature"', '1/1', 648, 'Individual', 'Patrick White', '1912-05-28', 'London', 'United Kingdom', 'Male', None, None, None, '1990-09-30', 'Sydney', 'Australia'),
#  (434, 1973, 'Peace', 'The Nobel Peace Prize 1973', None, '1/2', 530, 'Individual', 'Henry A. Kissinger', '1923-05-27', 'Fürth', 'Germany', 'Male', None, None, None, None, None, None),
#  (435, 1973, 'Peace', 'The Nobel Peace Prize 1973', None, '1/2', 531, 'Organization', 'Le Duc Tho', '1911-10-14', 'Nam Ha province', 'Vietnam', 'Male', None, None, None, '1990-10-13', 'Hanoi', 'Vietnam'),
#  (440, 1974, 'Economics', 'The Sveriges Riksbank Prize in Economic Sciences 1974', '"for their pioneering work in the theory of money and economic fluctuations and for their penetrating analysis of the interdependence of economic, social and institutional phenomena"', '1/2', 684, 'Individual', 'Gunnar Myrdal', '1898-12-06', 'Skattungbyn', 'Sweden', 'Male', None, None, None, '1987-05-17', 'Stockholm', 'Sweden'),
#  (441, 1974, 'Economics', 'The Sveriges Riksbank Prize in Economic Sciences 1974', '"for their pioneering work in the theory of money and economic fluctuations and for their penetrating analysis of the interdependence of economic, social and institutional phenomena"', '1/2', 685, 'Individual', 'Friedrich August von Hayek', '1899-05-08', 'Vienna', 'Austria', 'Male', None, None, None, '1992-03-23', 'Freiburg', 'Germany'),
#  (442, 1974, 'Literature', 'The Nobel Prize in Literature 1974', '"for a narrative art, far-seeing in lands and ages, in the service of freedom"', '1/2', 649, 'Individual', 'Eyvind Johnson', '1900-07-29', 'Svartbjörnsbyn', 'Sweden', 'Male', None, None, None, '1976-08-25', 'Stockholm', 'Sweden'),
#  (443, 1974, 'Literature', 'The Nobel Prize in Literature 1974', '"for writings that catch the dewdrop and reflect the cosmos"', '1/2', 650, 'Individual', 'Harry Martinson', '1904-05-06', 'Jämshög', 'Sweden', 'Male', None, None, None, '1978-02-11', 'Stockholm', 'Sweden'),
#  (447, 1974, 'Peace', 'The Nobel Peace Prize 1974', None, '1/2', 532, 'Individual', 'Seán MacBride', '1904-01-26', 'Paris', 'France', 'Male', None, None, None, '1988-01-15', 'Dublin', 'Ireland'),
#  (448, 1974, 'Peace', 'The Nobel Peace Prize 1974', None, '1/2', 533, 'Individual', 'Eisaku Sato', '1901-03-27', 'Tabuse', 'Japan', 'Male', None, None, None, '1975-06-03', 'Tokyo', 'Japan'),
#  (455, 1975, 'Literature', 'The Nobel Prize in Literature 1975', '"for his distinctive poetry which, with great artistic sensitivity, has interpreted human values under the sign of an outlook on life with no illusions"', '1/1', 651, 'Individual', 'Eugenio Montale', '1896-10-12', 'Genoa', 'Italy', 'Male', None, None, None, '1981-09-12', 'Milan', 'Italy'),
#  (459, 1975, 'Peace', 'The Nobel Peace Prize 1975', None, '1/1', 534, 'Individual', 'Andrei Dmitrievich Sakharov', '1921-05-21', 'Moscow', 'Russia', 'Male', None, None, None, '1989-12-14', 'Moscow', 'Union of Soviet Socialist Republics (Russia)'),
#  (465, 1976, 'Literature', 'The Nobel Prize in Literature 1976', '"for the human understanding and subtle analysis of contemporary culture that are combined in his work"', '1/1', 652, 'Individual', 'Saul Bellow', '1915-06-10', 'Montreal', 'Canada', 'Male', None, None, None, '2005-04-05', 'Brookline, MA', 'United States of America'),
#  (468, 1976, 'Peace', 'The Nobel Peace Prize 1976', None, '1/2', 535, 'Individual', 'Betty Williams', '1943-05-22', 'Belfast', 'Northern Ireland', 'Female', None, None, None, None, None, None),
#  (469, 1976, 'Peace', 'The Nobel Peace Prize 1976', None, '1/2', 536, 'Individual', 'Mairead Corrigan', '1944-01-27', 'Belfast', 'Northern Ireland', 'Female', None, None, None, None, None, None),
#  (475, 1977, 'Literature', 'The Nobel Prize in Literature 1977', '"for a creative poetic writing which illuminates man\'s condition in the cosmos and in present-day society, at the same time representing the great renewal of the traditions of Spanish poetry between the wars"', '1/1', 653, 'Individual', 'Vicente Aleixandre', '1898-04-26', 'Sevilla', 'Spain', 'Male', None, None, None, '1984-12-14', 'Madrid', 'Spain'),
#  (479, 1977, 'Peace', 'The Nobel Peace Prize 1977', None, '1/1', 537, 'Organization', 'Amnesty International', None, None, None, None, None, None, None, None, None, None),
#  (485, 1978, 'Literature', 'The Nobel Prize in Literature 1978', '"for his impassioned narrative art which, with roots in a Polish-Jewish cultural tradition, brings universal human conditions to life"', '1/1', 654, 'Individual', 'Isaac Bashevis Singer', '1904-07-14', 'Leoncin', 'Russian Empire (Poland)', 'Male', None, None, None, '1991-07-24', 'Surfside, FL', 'United States of America'),
#  (489, 1978, 'Peace', 'The Nobel Peace Prize 1978', None, '1/2', 538, 'Individual', 'Mohamed Anwar al-Sadat', '1918-12-25', 'Mit Abu al-Kawm', 'Egypt', 'Male', None, None, None, '1981-10-06', 'Cairo', 'Egypt'),
#  (490, 1978, 'Peace', 'The Nobel Peace Prize 1978', None, '1/2', 539, 'Individual', 'Menachem Begin', '1913-08-16', 'Brest Litovsk', 'Russian Empire (Belarus)', 'Male', None, None, None, '1992-03-09', 'Tel Aviv', 'Israel'),
#  (498, 1979, 'Literature', 'The Nobel Prize in Literature 1979', '"for his poetry, which, against the background of Greek tradition, depicts with sensuous strength and intellectual clear-sightedness modern man\'s struggle for freedom and creativeness"', '1/1', 655, 'Individual', 'Odysseus Elytis', '1911-11-02', 'Iráklion', 'Crete (Greece)', 'Male', None, None, None, '1996-03-18', 'Athens', 'Greece'),
#  (501, 1979, 'Peace', 'The Nobel Peace Prize 1979', None, '1/1', 540, 'Organization', 'Mother Teresa', '1910-08-26', 'Uskup (Skopje)', 'Ottoman Empire (Republic of Macedonia)', 'Female', None, None, None, '1997-09-05', 'Calcutta', 'India'),
#  (509, 1980, 'Literature', 'The Nobel Prize in Literature 1980', '"who with uncompromising clear-sightedness voices man\'s exposed condition in a world of severe conflicts"', '1/1', 657, 'Individual', 'Czeslaw Milosz', '1911-06-30', '&#346;eteniai', 'Russian Empire (Lithuania)', 'Male', None, None, None, '2004-08-14', 'Kraków', 'Poland'),
#  (513, 1980, 'Peace', 'The Nobel Peace Prize 1980', None, '1/1', 541, 'Individual', 'Adolfo Pérez Esquivel', '1931-11-26', 'Buenos Aires', 'Argentina', 'Male', None, None, None, None, None, None),
#  (519, 1981, 'Literature', 'The Nobel Prize in Literature 1981', '"for writings marked by a broad outlook, a wealth of ideas and artistic power"', '1/1', 658, 'Individual', 'Elias Canetti', '1905-07-25', 'Ruse', 'Bulgaria', 'Male', None, None, None, '1994-08-14', 'Zurich', 'Switzerland'),
#  (523, 1981, 'Peace', 'The Nobel Peace Prize 1981', None, '1/1', 515, 'Organization', 'Office of the United Nations High Commissioner for Refugees (UNHCR)', None, None, None, None, None, None, None, None, None, None),
#  (529, 1982, 'Literature', 'The Nobel Prize in Literature 1982', '"for his novels and short stories, in which the fantastic and the realistic are combined in a richly composed world of imagination, reflecting a continent\'s life and conflicts"', '1/1', 659, 'Individual', 'Gabriel García Márquez', '1927-03-06', 'Aracataca', 'Colombia', 'Male', None, None, None, '2014-04-17', 'Mexico City', 'Mexico'),
#  (533, 1982, 'Peace', 'The Nobel Peace Prize 1982', None, '1/2', 543, 'Individual', 'Alva Myrdal', '1902-01-31', 'Uppsala', 'Sweden', 'Female', None, None, None, '1986-02-01', 'Stockholm', 'Sweden'),
#  (534, 1982, 'Peace', 'The Nobel Peace Prize 1982', None, '1/2', 544, 'Individual', 'Alfonso García Robles', '1911-03-20', 'Zamora', 'Mexico', 'Male', None, None, None, '1991-09-02', 'Mexico City', 'Mexico'),
#  (538, 1983, 'Literature', 'The Nobel Prize in Literature 1983', '"for his novels which, with the perspicuity of realistic narrative art and the diversity and universality of myth, illuminate the human condition in the world of today"', '1/1', 660, 'Individual', 'William Golding', '1911-09-19', 'St. Columb Minor', 'United Kingdom', 'Male', None, None, None, '1993-06-19', 'Perranarworthal', 'United Kingdom'),
#  (540, 1983, 'Peace', 'The Nobel Peace Prize 1983', None, '1/1', 545, 'Individual', 'Lech Walesa', '1943-09-29', 'Popowo', 'Poland', 'Male', None, None, None, None, None, None),
#  (545, 1984, 'Literature', 'The Nobel Prize in Literature 1984', '"for his poetry which endowed with freshness, sensuality and rich inventiveness provides a liberating image of the indomitable spirit and versatility of man"', '1/1', 661, 'Individual', 'Jaroslav Seifert', '1901-09-23', 'Prague', 'Austria-Hungary (Czech Republic)', 'Male', None, None, None, '1986-01-10', 'Prague', 'Czechoslovakia'),
# ...
#  (788, 2006, 'Peace', 'The Nobel Peace Prize 2006', '"for their efforts to create economic and social development from below"', '1/2', 809, 'Individual', 'Muhammad Yunus', '1940-06-28', 'Chittagong', 'British India (Bangladesh)', 'Male', None, None, None, None, None, None),
#  (789, 2006, 'Peace', 'The Nobel Peace Prize 2006', '"for their efforts to create economic and social development from below"', '1/2', 810, 'Organization', 'Grameen Bank', None, None, None, None, None, None, None, None, None, None),
#  (796, 2007, 'Literature', 'The Nobel Prize in Literature 2007', '"that epicist of the female experience, who with scepticism, fire and visionary power has subjected a divided civilisation to scrutiny"', '1/1', 817, 'Individual', 'Doris Lessing', '1919-10-22', 'Kermanshah', 'Persia (Iran)', 'Female', None, None, None, '2013-11-17', 'London', 'United Kingdom'),
#  (800, 2007, 'Peace', 'The Nobel Peace Prize 2007', '"for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change"', '1/2', 818, 'Organization', 'Intergovernmental Panel on Climate Change (IPCC)', None, None, None, None, None, None, None, None, None, None),
#  (801, 2007, 'Peace', 'The Nobel Peace Prize 2007', '"for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change"', '1/2', 819, 'Individual', 'Albert Arnold (Al) Gore Jr.', '1948-03-31', 'Washington, DC', 'United States of America', 'Male', None, None, None, None, None, None),
#  (808, 2008, 'Literature', 'The Nobel Prize in Literature 2008', '"author of new departures, poetic adventure and sensual ecstasy, explorer of a humanity beyond and below the reigning civilization"', '1/1', 832, 'Individual', 'Jean-Marie Gustave Le Clézio', '1940-04-13', 'Nice', 'France', 'Male', None, None, None, None, None, None),
#  (812, 2008, 'Peace', 'The Nobel Peace Prize 2008', '"for his important efforts, on several continents and over more than three decades, to resolve international conflicts"', '1/1', 833, 'Individual', 'Martti Ahtisaari', '1937-06-23', 'Viipuri (Vyborg)', 'Finland', 'Male', None, None, None, None, None, None),
#  (821, 2009, 'Literature', 'The Nobel Prize in Literature 2009', '"who, with the concentration of poetry and the frankness of prose, depicts the landscape of the dispossessed"', '1/1', 844, 'Individual', 'Herta Müller', '1953-08-17', 'Nitzkydorf, Banat', 'Romania', 'Female', None, None, None, None, None, None),
#  (825, 2009, 'Peace', 'The Nobel Peace Prize 2009', '"for his extraordinary efforts to strengthen international diplomacy and cooperation between peoples"', '1/1', 845, 'Individual', 'Barack H. Obama', '1961-08-04', 'Honolulu, HI', 'United States of America', 'Male', None, None, None, None, None, None),
#  (829, 2010, 'Chemistry', 'The Nobel Prize in Chemistry 2010', '"for palladium-catalyzed cross couplings in organic synthesis"', '1/3', 851, 'Individual', 'Richard F. Heck', '1931-08-15', 'Springfield, MA', 'United States of America', 'Male', 'University of Delaware', None, 'United States of America', '2015-10-09', 'Manila', 'Philippines'),
#  (835, 2010, 'Literature', 'The Nobel Prize in Literature 2010', '"for his cartography of structures of power and his trenchant images of the individual\'s resistance, revolt, and defeat"', '1/1', 854, 'Individual', 'Mario Vargas Llosa', '1936-03-28', 'Arequipa', 'Peru', 'Male', None, None, None, None, None, None),
#  (837, 2010, 'Peace', 'The Nobel Peace Prize 2010', '"for his long and non-violent struggle for fundamental human rights in China"', '1/1', 855, 'Individual', 'Liu Xiaobo', '1955-12-28', None, 'China', 'Male', None, None, None, None, None, None),
#  (843, 2011, 'Literature', 'The Nobel Prize in Literature 2011', '"because, through his condensed, translucent images, he gives us fresh access to reality"', '1/1', 868, 'Individual', 'Tomas Tranströmer', '1931-04-15', 'Stockholm', 'Sweden', 'Male', None, None, None, '2015-03-26', 'Stockholm', 'Sweden'),
#  (847, 2011, 'Peace', 'The Nobel Peace Prize 2011', '"for their non-violent struggle for the safety of women and for women&apos;s rights to full participation in peace-building work"', '1/3', 869, 'Individual', 'Ellen Johnson Sirleaf', '1938-10-29', 'Monrovia', 'Liberia', 'Female', None, None, None, None, None, None),
#  (848, 2011, 'Peace', 'The Nobel Peace Prize 2011', '"for their non-violent struggle for the safety of women and for women&apos;s rights to full participation in peace-building work"', '1/3', 870, 'Individual', 'Leymah Gbowee', '1972-02-01', 'Monrovia', 'Liberia', 'Female', None, None, None, None, None, None),
#  (849, 2011, 'Peace', 'The Nobel Peace Prize 2011', '"for their non-violent struggle for the safety of women and for women&apos;s rights to full participation in peace-building work"', '1/3', 871, 'Individual', 'Tawakkol Karman', '1979-02-07', "Ta'izz", 'Yemen', 'Female', None, None, None, None, None, None),
#  (853, 2012, 'Chemistry', 'The Nobel Prize in Chemistry 2012', '"for studies of G-protein-coupled receptors"', '1/2', 878, 'Individual', 'Robert J. Lefkowitz', '1943-04-15', 'New York, NY', 'United States of America', 'Male', 'Howard Hughes Medical Institute', None, None, None, None, None),
#  (857, 2012, 'Literature', 'The Nobel Prize in Literature 2012', '"who with hallucinatory realism merges folk tales, history and the contemporary"', '1/1', 880, 'Individual', 'Mo Yan', '1955-02-02', 'Gaomi', 'China', 'Male', None, None, None, None, None, None),
#  (860, 2012, 'Peace', 'The Nobel Peace Prize 2012', '"for over six decades contributed to the advancement of peace and reconciliation, democracy and human rights in Europe"', '1/1', 881, 'Organization', 'European Union (EU)', None, None, None, None, None, None, None, None, None, None),
#  (869, 2013, 'Literature', 'The Nobel Prize in Literature 2013', '"master of the contemporary short story"', '1/1', 892, 'Individual', 'Alice Munro', '1931-07-10', 'Wingham', 'Canada', 'Female', None, None, None, None, None, None),
#  (873, 2013, 'Peace', 'The Nobel Peace Prize 2013', '"for its extensive efforts to eliminate chemical weapons"', '1/1', 893, 'Organization', 'Organisation for the Prohibition of Chemical Weapons (OPCW)', None, None, None, None, None, None, None, None, None, None),
#  (880, 2014, 'Literature', 'The Nobel Prize in Literature 2014', '"for the art of memory with which he has evoked the most ungraspable human destinies and uncovered the life-world of the occupation"', '1/1', 912, 'Individual', 'Patrick Modiano', '1945-07-30', 'Paris', 'France', 'Male', None, None, None, None, None, None),
#  (884, 2014, 'Peace', 'The Nobel Peace Prize 2014', '"for their struggle against the suppression of children and young people and for the right of all children to education"', '1/2', 913, 'Individual', 'Kailash Satyarthi', '1954-01-11', 'Vidisha', 'India', 'Male', None, None, None, None, None, None),
#  (885, 2014, 'Peace', 'The Nobel Peace Prize 2014', '"for their struggle against the suppression of children and young people and for the right of all children to education"', '1/2', 914, 'Individual', 'Malala Yousafzai', '1997-07-12', 'Mingora', 'Pakistan', 'Female', None, None, None, None, None, None),
#  (893, 2015, 'Literature', 'The Nobel Prize in Literature 2015', '"for her polyphonic writings, a monument to suffering and courage in our time"', '1/1', 924, 'Individual', 'Svetlana Alexievich', '1948-05-31', 'Ivano-Frankivsk', 'Ukraine', 'Female', None, None, None, None, None, None),
#  (897, 2015, 'Peace', 'The Nobel Peace Prize 2015', '"for its decisive contribution to the building of a pluralistic democracy in Tunisia in the wake of the Jasmine Revolution of 2011"', '1/1', 925, 'Organization', 'National Dialogue Quartet', None, None, None, None, None, None, None, None, None, None),
#  (905, 2016, 'Literature', 'The Nobel Prize in Literature 2016', '"for having created new poetic expressions within the great American song tradition"', '1/1', 937, 'Individual', 'Bob Dylan', '1941-05-24', 'Duluth, MN', 'United States of America', 'Male', None, None, None, None, None, None),
#  (907, 2016, 'Peace', 'The Nobel Peace Prize 2016', '"for his resolute efforts to bring the country\'s more than 50-year-long civil war to an end"', '1/1', 934, 'Individual', 'Juan Manuel Santos', '1951-08-10', 'Bogotá', 'Colombia', 'Male', None, None, None, None, None, None),
#  (914, 2017, 'Physics', 'The Nobel Prize in Physics 2017', '"for decisive contributions to the LIGO detector and the observation of gravitational waves"', '1/2', 941, 'Individual', 'Rainer Weiss', '1932-09-29', 'Berlin', 'Germany', 'Male', 'LIGO/VIRGO Collaboration', None, None, None, None, None),
#  (915, 2017, 'Physics', 'The Nobel Prize in Physics 2017', '"for decisive contributions to the LIGO detector and the observation of gravitational waves"', '1/4', 942, 'Individual', 'Barry C. Barish', '1936-01-27', 'Omaha, NE', 'United States of America', 'Male', 'LIGO/VIRGO Collaboration', None, None, None, None, None),
#  (916, 2017, 'Physics', 'The Nobel Prize in Physics 2017', '"for decisive contributions to the LIGO detector and the observation of gravitational waves"', '1/4', 943, 'Individual', 'Kip S. Thorne', '1940-06-01', 'Logan, UT', 'United States of America', 'Male', 'LIGO/VIRGO Collaboration', None, None, None, None, None),
#  (920, 2017, 'Literature', 'The Nobel Prize in Literature 2017', '"who in novels of great emotional force has uncovered the abyss beneath our illusory sense of connection with the world"', '1/1', 947, 'Individual', 'Kazuo Ishiguro', '1954-11-08', 'Nagasaki', 'Japan', 'Male', None, None, None, None, None, None),
#  (921, 2017, 'Peace', 'The Nobel Peace Prize 2017', '"for its work to draw attention to the catastrophic humanitarian consequences of any use of nuclear weapons and for its ground-breaking efforts to achieve a treaty-based prohibition of such weapons"', '1/1', 948, 'Organization', 'International Campaign to Abolish Nuclear Weapons', None, None, None, None, None, None, None, None, None, None),
#  (931, 2018, 'Peace', 'The Nobel Peace Prize 2018', '"for their efforts to end the use of sexual violence as a weapon of war and armed conflict"', '1/2', 966, 'Individual', 'Denis Mukwege', '1955-03-01', 'Bukavu', 'Belgian Congo (now Democratic Republic of the Congo)', 'Male', None, None, None, None, None, None),
#  (932, 2018, 'Peace', 'The Nobel Peace Prize 2018', '"for their efforts to end the use of sexual violence as a weapon of war and armed conflict"', '1/2', 967, 'Individual', 'Nadia Murad', '1993-00-00', 'Kojo', 'Iraq', 'Female', None, None, None, None, None, None),
#  (935, 2018, 'Literature', 'The Nobel Prize in Literature 2018', '"for a narrative imagination that with encyclopedic passion represents the crossing of boundaries as a form of life"', '1/1', 979, 'Individual', 'Olga Tokarczuk', '1962-01-29', 'Sulechów', 'Poland', 'Female', None, None, None, None, None, None),
#  (945, 2019, 'Literature', 'The Nobel Prize in Literature 2019', '"for an influential work that with linguistic ingenuity has explored the periphery and the specificity of human experience"', '1/1', 980, 'Individual', 'Peter Handke', '1942-12-06', 'Griffen', 'Austria', 'Male', None, None, None, None, None, None),
#  (946, 2019, 'Peace', 'The Nobel Peace Prize 2019', '"for his efforts to achieve peace and international cooperation and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea"', '1/1', 981, 'Individual', 'Abiy Ahmed Ali', '1976-08-15', 'Beshasha', 'Ethiopia', 'Male', None, None, None, None, None, None),
#  (958, 2020, 'Literature', 'The Nobel Prize in Literature 2020', '"for her unmistakable poetic voice that with austere beauty makes individual existence universal"', '1/1', 993, 'Individual', 'Louise Glück', '1943-04-22', 'New York, NY', 'United States of America', 'Female', None, None, None, '2023-10-13', 'Cambridge, MA', 'United States of America'),
#  (959, 2020, 'Peace', 'The Nobel Peace Prize 2020', '"for its efforts to combat hunger for its contribution to bettering conditions for peace in conflict-affected areas and for acting as a driving force in efforts to prevent the use of hunger as a weapon of war and conflict"', '1/1', 994, 'Organization', 'World Food Programme', None, None, None, None, None, None, None, None, None, None),
#  (969, 2021, 'Literature', 'The Nobel Prize in Literature 2021', '"for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents"', '1/1', 1004, 'Individual', 'Abdulrazak Gurnah', '1948-00-00', None, None, 'Male', None, None, None, None, None, None),
#  (970, 2021, 'Peace', 'The Nobel Peace Prize 2021', '"for their efforts to safeguard freedom of expression which is a precondition for democracy and lasting peace"', '1/2', 1005, 'Individual', 'Maria Ressa', '1963-10-02', 'Manila', 'Philippines', 'Female', None, None, None, None, None, None),
#  (971, 2021, 'Peace', 'The Nobel Peace Prize 2021', '"for their efforts to safeguard freedom of expression which is a precondition for democracy and lasting peace"', '1/2', 1006, 'Individual', 'Dmitry Muratov', '1961-00-00', 'Kubyshev (now Samara)', 'USSR (now Russia)', 'Male', None, None, None, None, None, None),
#  (982, 2022, 'Literature', 'The Nobel Prize in Literature 2022', '"for the courage and clinical acuity with which she uncovers the roots estrangements and  collective restraints of personal memory"', '1/1', 1017, 'Individual', 'Annie Ernaux', '1940-09-01', 'Lillebonne', 'France', 'Female', None, None, None, None, None, None),
#  (983, 2022, 'Peace', 'The Nobel Peace Prize 2022', '"The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protec ... (77 characters truncated) ...  document war crimes human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy."', '1/3', 1018, 'Individual', 'Ales Bialiatski', '1962-09-25', 'Vyartsilya Karelia', 'Russia', 'Male', None, None, None, None, None, None),
#  (984, 2022, 'Peace', 'The Nobel Peace Prize 2022', '"The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protec ... (77 characters truncated) ...  document war crimes human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy."', '1/3', 1019, 'Organization', 'Memorial', None, None, None, None, None, None, None, None, None, None),
#  (985, 2022, 'Peace', 'The Nobel Peace Prize 2022', '"The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protec ... (77 characters truncated) ...  document war crimes human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy."', '1/3', 1020, 'Organization', 'Center for Civil Liberties', None, None, None, None, None, None, None, None, None, None),
#  (997, 2023, 'Literature', 'The Nobel Prize in Literature 2023', '"for his innovative plays and prose which give voice to the unsayable"', '1/1', 1032, 'Individual', 'Jon Fosse', '1959-09-29', 'Haugesund', 'Norway', 'Male', None, None, None, None, None, None),
#  (998, 2023, 'Peace', 'The Nobel Peace Prize 2023', '"for her fight against the oppression of women in Iran and her fight to promote human rights and freedom for all"', '1/1', 1033, 'Individual', 'Narges Mohammadi', '1972-04-21', 'Zanjan', 'Iran', 'Female', None, None, None, None, None, None)]

# %%
# %%sql
# /* As noticed earlier, organizations are suprisingly missing information
# in organization_name, _city, and _country columns. Otherwise it seems that the most missing
# values are related to Nobel Prizes in category of Peace and Literature.
# Lets check which laureates in these two categories have values at organization columns */
#
# SELECT *
# FROM nobel
# WHERE (category = 'Peace' OR
# category = 'Literature')
# AND (organization_name IS NOT NULL
# OR organization_city IS NOT NULL
# OR organization_country IS NOT NULL);
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(41, 1907, 'Peace', 'The Nobel Peace Prize 1907', None, '1/2', 472, 'Individual', 'Louis Renault', '1843-05-21', 'Autun', 'France', 'Male', 'Sorbonne University', 'Paris', 'France', '1918-02-08', 'Barbizon', 'France'),
#  (161, 1931, 'Peace', 'The Nobel Peace Prize 1931', None, '1/2', 497, 'Individual', 'Nicholas Murray Butler', '1862-04-02', 'Elizabeth, NJ', 'United States of America', 'Male', 'Columbia University', 'New York, NY', 'United States of America', '1947-12-07', 'New York, NY', 'United States of America'),
#  (256, 1950, 'Peace', 'The Nobel Peace Prize 1950', None, '1/1', 511, 'Individual', 'Ralph Bunche', '1904-08-07', 'Detroit, MI', 'United States of America', 'Male', 'Harvard University', 'Cambridge, MA', 'United States of America', '1971-12-09', 'New York, NY', 'United States of America'),
#  (340, 1962, 'Peace', 'The Nobel Peace Prize 1962', None, '1/1', 217, 'Individual', 'Linus Carl Pauling', '1901-02-28', 'Portland, OR', 'United States of America', 'Male', 'California Institute of Technology (Caltech)', 'Pasadena, CA', 'United States of America', '1994-08-19', 'Big Sur, CA', 'United States of America')]

# %%
# %%sql
# /* Seems that almost all prizes in category of Peace and all in Literature
# were given to individuals or organizations who are not part of any organization.
# LEts briefly check how many prizes was given in each of the two categories
# to see if it is close to number of missing values (ca 265) in organization columns*/
#
# SELECT COUNT(category) AS nr_prizes_in_peace_or_literature
# FROM nobel
# WHERE (category = 'Peace' OR
# category = 'Literature');
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(261,)]

# %% [markdown]
# ### Summary on missing values
# We found out that motivation of Nobel Prize was not being announced for almost first 90 years of this prize existence.
#
# Further, most of the missing values related to birth and sex are connected to awarded organizations and few individuals. While there are only two individuals with missing birth date, the organizations are missing birth dates almost always. However, there are four exceptional records which are assigned as organizations but are clearly related to known individuals such as Dalai Lama or Mother Teresa. Note that missing birth dates in the case of organizations will be beneficial in following analysis when we will calculate lenght of life because it cannot be calculated without birth date; therefore, we can be sure all results will be related to individuals and not to organizations.
#
# Finally, values missing in organization columns (_name, _city, _country) belongs to cases where laureate_type is organization or cases where category is peace or literature. Indeed, this makes sense and indicates that organizations in organization columns are scientific institutions where was working awarded individual. Nobel Prizes in peace and literature are not related to scientific research; therefore, there is no organization to add.

# %% [markdown]
# ## Let's dive into interesting stuff
# From now on the cells are focused on finding out interesting information.
#
# ### Who won the most Nobel Prizes?
# We will approach this questions from different points of view. We will look on individuals as well as organizations or countries.

# %%
# %%sql
# /* Who won more than one Nobel Prize? */
#
# SELECT full_name,
#     COUNT(laureate_id) AS nr_of_prizes,
#     sex,
#     birth_date,
#     death_date,
#     birth_country,
#     death_country
# FROM nobel
# GROUP BY laureate_id
# HAVING COUNT(laureate_id)>1
# ORDER BY nr_of_prizes DESC, birth_date DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Comité international de la Croix Rouge (International Committee of the Red Cross)', 3, None, None, None, None, None),
#  ('K. Barry Sharpless', 2, 'Male', '1941-04-28', None, 'United States of America', None),
#  ('Frederick Sanger', 2, 'Male', '1918-08-13', '2013-11-19', 'United Kingdom', 'United Kingdom'),
#  ('John Bardeen', 2, 'Male', '1908-05-23', '1991-01-30', 'United States of America', 'United States of America'),
#  ('Linus Carl Pauling', 2, 'Male', '1901-02-28', '1994-08-19', 'United States of America', 'United States of America'),
#  ('Marie Curie, née Sklodowska', 2, 'Female', '1867-11-07', '1934-07-04', 'Russian Empire (Poland)', 'France'),
#  ('Office of the United Nations High Commissioner for Refugees (UNHCR)', 2, None, None, None, None, None)]

# %%
# %%sql
# /* Record holds Red Cross, lets check in which years it was awarded */
#
# SELECT
#     full_name,
#     year,
#     category,
#     prize_share
# FROM nobel
# WHERE full_name LIKE "%Red Cross%";
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Comité international de la Croix Rouge (International Committee of the Red Cross)', 1917, 'Peace', '1/1'),
#  ('Comité international de la Croix Rouge (International Committee of the Red Cross)', 1944, 'Peace', '1/1'),
#  ('Comité international de la Croix Rouge (International Committee of the Red Cross)', 1963, 'Peace', '1/2'),
#  ('Ligue des Sociétés de la Croix-Rouge (League of Red Cross Societies)', 1963, 'Peace', '1/2')]

# %%
# %%sql
# /* From which countries are comming laureates mostly? */
#
# SELECT birth_country, COUNT(*) AS nr_prizes_birth
# FROM nobel
# WHERE birth_country IS NOT NULL
# GROUP BY birth_country
# ORDER BY nr_prizes_birth DESC, birth_country ASC
# LIMIT 15;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('United States of America', 291),
#  ('United Kingdom', 91),
#  ('Germany', 67),
#  ('France', 58),
#  ('Sweden', 30),
#  ('Japan', 28),
#  ('Canada', 21),
#  ('Netherlands', 19),
#  ('Switzerland', 19),
#  ('Italy', 18),
#  ('Russia', 18),
#  ('Austria', 16),
#  ('Norway', 13),
#  ('Denmark', 12),
#  ('China', 11)]

# %%
# %%sql
# /* How many laureates worked in other country than the country of birth? */
#
# WITH country_difference AS(SELECT
#     CASE WHEN organization_country = birth_country THEN 'Birth and organization in the same country'
#     WHEN organization_country <> birth_country THEN 'Birth and organization in different countries'
#     WHEN organization_country IS NULL OR birth_country IS NULL THEN 'Birth or organization country unknown'
#     ELSE 'unexpected' END AS status
#     FROM nobel)
# SELECT status,COUNT(*) AS number_of_prizes
# FROM country_difference
# GROUP BY status
# ORDER BY number_of_prizes DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Birth and organization in the same country', 464),
#  ('Birth and organization in different countries', 271),
#  ('Birth or organization country unknown', 265)]

# %%
# %%sql
# /* What is the difference in number of awards by birth_country and organization_country? */
#
# WITH organization AS (
#     SELECT organization_country, COUNT(*) AS nr_prizes_org
#     FROM nobel
#     GROUP BY organization_country),
# birth_nobel AS (
#     SELECT birth_country, COUNT(*) AS nr_prizes_birth
#     FROM nobel
#     GROUP BY birth_country)
# SELECT organization_country, nr_prizes_org, nr_prizes_birth, (nr_prizes_org-nr_prizes_birth) AS org_over_birth_nr
# FROM organization AS org
# JOIN birth_nobel AS birth
# ON org.organization_country = birth.birth_country
# ORDER BY org_over_birth_nr DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('United States of America', 385, 291, 94),
#  ('Switzerland', 24, 19, 5),
#  ('United Kingdom', 93, 91, 2),
#  ('Finland', 1, 2, -1),
#  ('Portugal', 1, 2, -1),
#  ('Argentina', 2, 4, -2),
#  ('Denmark', 9, 12, -3),
#  ('Belgium', 5, 9, -4),
#  ('Ireland', 1, 5, -4),
#  ('Australia', 5, 10, -5),
#  ('Hungary', 2, 8, -6),
#  ('Spain', 1, 7, -6),
#  ('India', 1, 8, -7),
#  ('Netherlands', 11, 19, -8),
#  ('Norway', 5, 13, -8),
#  ('Austria', 7, 16, -9),
#  ('China', 1, 11, -10),
#  ('Japan', 18, 28, -10),
#  ('Italy', 7, 18, -11),
#  ('Canada', 9, 21, -12),
#  ('Sweden', 18, 30, -12),
#  ('Russia', 3, 18, -15),
#  ('Germany', 49, 67, -18),
#  ('France', 38, 58, -20)]

# %%
# %%sql
# /* There are many famous universities and research institutes in the world.
# How they stand in the number of Nobel Prizes awarded to their scientist? */
#
# SELECT
#     organization_name,
#     organization_country,
#     COUNT(*) AS prizes_nr
# FROM nobel
# WHERE organization_country IS NOT NULL
# GROUP BY organization_name
# HAVING COUNT(*) > 9
# ORDER BY prizes_nr DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('University of California', 'United States of America', 36),
#  ('Harvard University', 'United States of America', 28),
#  ('Stanford University', 'United States of America', 22),
#  ('Massachusetts Institute of Technology (MIT)', 'United States of America', 22),
#  ('University of Chicago', 'United States of America', 19),
#  ('University of Cambridge', 'United Kingdom', 17),
#  ('Princeton University', 'United States of America', 17),
#  ('Columbia University', 'United States of America', 17),
#  ('California Institute of Technology (Caltech)', 'United States of America', 17),
#  ('Rockefeller University', 'United States of America', 13),
#  ('University of Oxford', 'United Kingdom', 10),
#  ('MRC Laboratory of Molecular Biology', 'United Kingdom', 10)]

# %%
# %%sql
# WITH prizes_org AS (
#     SELECT COUNT(*) AS prizes_nr
#     FROM nobel
#     WHERE organization_country IS NOT NULL
#     GROUP BY organization_name
#     HAVING COUNT(*) > 9)
# SELECT
#     COUNT(prizes_nr) AS nr_organizations_with_10_or_more_laureates,
#     SUM(prizes_nr) AS total_nr_prizes_for_top_organizations
# FROM prizes_org;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(12, 228)]

# %%
# %%sql
# /* As I am from Czech Republic, we will look up which laureates were from Czechia or worked in Czech organization */
#
# SELECT
#     full_name,
#     year AS year_awarded,
#     strftime('%Y', death_date) AS year_of_death,
#     ROUND((julianday(death_date) - julianday(birth_date))/365.2422,1) AS life_length,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE birth_country LIKE '%Cz%'
# OR organization_country LIKE '%Cz%'
# ORDER BY year_awarded ASC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Baroness Bertha Sophie Felicita von Suttner, née Countess Kinsky von Chinic und Tettau', 1905, '1914', 71.0, 'Peace', None, 'Austrian Empire (Czech Republic)', None),
#  ('Carl Ferdinand Cori', 1947, '1984', 87.9, 'Medicine', '"for their discovery of the course of the catalytic conversion of glycogen"', 'Austria-Hungary (Czech Republic)', 'United States of America'),
#  ('Gerty Theresa Cori, née Radnitz', 1947, '1957', 61.2, 'Medicine', '"for their discovery of the course of the catalytic conversion of glycogen"', 'Austria-Hungary (Czech Republic)', 'United States of America'),
#  ('Jaroslav Heyrovsky', 1959, '1967', 76.3, 'Chemistry', '"for his discovery and development of the polarographic methods of analysis"', 'Austria-Hungary (Czech Republic)', 'Czechoslovakia'),
#  ('Jaroslav Seifert', 1984, '1986', 84.3, 'Literature', '"for his poetry which endowed with freshness, sensuality and rich inventiveness provides a liberating image of the indomitable spirit and versatility of man"', 'Austria-Hungary (Czech Republic)', None),
#  ('Peter Grünberg', 2007, None, None, 'Physics', '"for the discovery of Giant Magnetoresistance"', 'Czechoslovakia (Czech Republic)', 'Germany')]

# %% [markdown]
# ### Is there a day or month to be born which makes you more likely to get Nobel Prize?

# %%
# %%sql
# /* First, lets look on birthdays. */
#
# SELECT
# strftime('%m/%d',birth_date) AS birthday,
# COUNT(*) AS nr_people
# FROM nobel
# WHERE birthday IS NOT NULL
# GROUP BY birthday
# ORDER BY nr_people DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('02/28', 8),
#  ('10/10', 7),
#  ('06/28', 7),
#  ('05/21', 7),
#  ('12/11', 6),
#  ('11/30', 6),
#  ('11/07', 6),
#  ('10/30', 6),
#  ('10/02', 6),
#  ('09/30', 6),
#  ('09/29', 6),
#  ('09/06', 6),
#  ('08/23', 6),
#  ('07/12', 6),
#  ('06/06', 6),
#  ('05/31', 6),
#  ('02/19', 6),
#  ('01/23', 6),
#  ('10/19', 5),
#  ('10/09', 5),
#  ('09/21', 5),
#  ('09/14', 5),
#  ('09/12', 5),
#  ('09/03', 5),
#  ('08/30', 5),
#  ('08/25', 5),
#  ('08/16', 5),
#  ('07/02', 5),
#  ('07/01', 5),
#  ('06/13', 5),
#  ('06/08', 5),
#  ('05/22', 5),
#  ('05/20', 5),
#  ('04/23', 5),
#  ('04/22', 5),
#  ('04/15', 5),
#  ('03/31', 5),
#  ('03/28', 5),
#  ('03/24', 5),
#  ('03/15', 5),
#  ('01/31', 5),
#  ('01/27', 5),
#  ('12/25', 4),
#  ('12/22', 4),
#  ('12/18', 4),
#  ('12/09', 4),
#  ('12/05', 4),
#  ('12/03', 4),
#  ('11/22', 4),
#  ('11/20', 4),
#  ('11/19', 4),
#  ('10/22', 4),
#  ('10/21', 4),
#  ('10/08', 4),
#  ('09/27', 4),
#  ('09/13', 4),
#  ('09/04', 4),
#  ('08/27', 4),
#  ('08/15', 4),
#  ('08/13', 4),
#  ('08/07', 4),
#  ('07/29', 4),
#  ('07/18', 4),
#  ('07/05', 4),
#  ('06/25', 4),
#  ('06/19', 4),
#  ('06/18', 4),
#  ('06/16', 4),
#  ('06/15', 4),
#  ('06/07', 4),
#  ('06/03', 4),
#  ('05/24', 4),
#  ('05/23', 4),
#  ('05/18', 4),
#  ('05/15', 4),
#  ('05/08', 4),
#  ('05/03', 4),
#  ('04/26', 4),
#  ('04/21', 4),
#  ('04/20', 4),
#  ('04/13', 4),
#  ('04/06', 4),
#  ('04/01', 4),
#  ('03/29', 4),
#  ('03/27', 4),
#  ('03/26', 4),
#  ('03/23', 4),
#  ('03/07', 4),
#  ('02/10', 4),
#  ('02/09', 4),
#  ('02/07', 4),
#  ('01/30', 4),
#  ('01/29', 4),
#  ('01/15', 4),
#  ('01/04', 4),
#  ('01/01', 4),
#  ('12/30', 3),
#  ('12/28', 3),
#  ('12/26', 3),
#  ('12/19', 3),
#  ('12/15', 3),
#  ('12/13', 3),
#  ('12/06', 3),
#  ('12/01', 3),
#  ('11/26', 3),
#  ('11/23', 3),
#  ('11/18', 3),
#  ('11/09', 3),
#  ('11/05', 3),
#  ('11/04', 3),
#  ('11/02', 3),
#  ('11/01', 3),
#  ('10/25', 3),
#  ('10/20', 3),
#  ('10/16', 3),
#  ('10/07', 3),
#  ('10/06', 3),
#  ('10/05', 3),
#  ('10/04', 3),
#  ('10/03', 3),
#  ('09/25', 3),
#  ('09/24', 3),
#  ('09/23', 3),
#  ('09/16', 3),
#  ('09/08', 3),
#  ('09/02', 3),
#  ('09/01', 3),
#  ('08/29', 3),
#  ('08/28', 3),
#  ('08/26', 3),
#  ('08/24', 3),
#  ('08/20', 3),
#  ('08/10', 3),
#  ('08/08', 3),
#  ('08/04', 3),
#  ('08/01', 3),
#  ('07/31', 3),
#  ('07/28', 3),
#  ('07/26', 3),
#  ('07/25', 3),
#  ('07/20', 3),
#  ('07/19', 3),
#  ('07/15', 3),
#  ('07/14', 3),
#  ('07/10', 3),
#  ('07/06', 3),
#  ('06/24', 3),
#  ('06/23', 3),
#  ('06/22', 3),
#  ('06/21', 3),
#  ('06/17', 3),
#  ('05/30', 3),
#  ('05/27', 3),
#  ('05/25', 3),
#  ('05/16', 3),
#  ('05/11', 3),
#  ('05/07', 3),
#  ('05/06', 3),
#  ('04/28', 3),
#  ('04/25', 3),
#  ('04/19', 3),
#  ('04/18', 3),
#  ('04/14', 3),
#  ('04/10', 3),
#  ('04/08', 3),
#  ('03/19', 3),
#  ('03/16', 3),
#  ('03/01', 3),
#  ('02/27', 3),
#  ('02/20', 3),
#  ('02/15', 3),
#  ('02/14', 3),
#  ('02/01', 3),
#  ('01/25', 3),
#  ('01/13', 3),
#  ('01/11', 3),
#  ('12/31', 2),
#  ('12/29', 2),
#  ('12/23', 2),
#  ('12/21', 2),
#  ('12/20', 2),
#  ('12/14', 2),
#  ('12/12', 2),
#  ('12/10', 2),
#  ('12/08', 2),
#  ('12/02', 2),
#  ('11/27', 2),
#  ('11/24', 2),
#  ('11/17', 2),
#  ('11/15', 2),
#  ('11/12', 2),
#  ('11/10', 2),
#  ('11/08', 2),
#  ('11/03', 2),
#  ('10/31', 2),
#  ('10/29', 2),
#  ('10/27', 2),
#  ('10/24', 2),
#  ('10/23', 2),
#  ('10/15', 2),
#  ('10/14', 2),
#  ('10/12', 2),
#  ('10/11', 2),
#  ('10/01', 2),
#  ('09/26', 2),
#  ('09/22', 2),
#  ('09/19', 2),
#  ('09/18', 2),
#  ('09/15', 2),
#  ('09/11', 2),
#  ('09/09', 2),
#  ('09/07', 2),
#  ('08/21', 2),
#  ('08/17', 2),
#  ('08/14', 2),
#  ('08/12', 2),
#  ('08/11', 2),
#  ('08/09', 2),
#  ('07/30', 2),
#  ('07/27', 2),
#  ('07/23', 2),
#  ('07/22', 2),
#  ('07/21', 2),
#  ('07/16', 2),
#  ('07/09', 2),
#  ('06/30', 2),
#  ('06/27', 2),
#  ('06/26', 2),
#  ('06/14', 2),
#  ('06/12', 2),
#  ('06/11', 2),
#  ('06/09', 2),
#  ('06/05', 2),
#  ('06/04', 2),
#  ('06/02', 2),
#  ('06/01', 2),
#  ('05/29', 2),
#  ('05/28', 2),
#  ('05/19', 2),
#  ('05/17', 2),
#  ('05/12', 2),
#  ('05/10', 2),
#  ('05/09', 2),
#  ('05/05', 2),
#  ('04/30', 2),
#  ('04/29', 2),
#  ('04/27', 2),
#  ('04/24', 2),
#  ('04/12', 2),
#  ('04/07', 2),
#  ('03/22', 2),
#  ('03/20', 2),
#  ('03/18', 2),
#  ('03/14', 2),
#  ('03/13', 2),
#  ('03/11', 2),
#  ('03/10', 2),
#  ('03/09', 2),
#  ('03/08', 2),
#  ('03/05', 2),
#  ('03/03', 2),
#  ('02/26', 2),
#  ('02/24', 2),
#  ('02/23', 2),
#  ('02/22', 2),
#  ('02/21', 2),
#  ('02/05', 2),
#  ('02/02', 2),
#  ('01/28', 2),
#  ('01/26', 2),
#  ('01/22', 2),
#  ('01/20', 2),
#  ('01/18', 2),
#  ('01/17', 2),
#  ('01/14', 2),
#  ('01/12', 2),
#  ('01/10', 2),
#  ('01/09', 2),
#  ('01/08', 2),
#  ('01/05', 2),
#  ('12/24', 1),
#  ('12/17', 1),
#  ('12/16', 1),
#  ('12/04', 1),
#  ('11/29', 1),
#  ('11/28', 1),
#  ('11/16', 1),
#  ('11/14', 1),
#  ('11/13', 1),
#  ('11/11', 1),
#  ('11/06', 1),
#  ('10/28', 1),
#  ('10/26', 1),
#  ('10/18', 1),
#  ('09/28', 1),
#  ('09/20', 1),
#  ('09/17', 1),
#  ('09/10', 1),
#  ('08/31', 1),
#  ('08/19', 1),
#  ('08/18', 1),
#  ('08/06', 1),
#  ('08/05', 1),
#  ('08/03', 1),
#  ('08/02', 1),
#  ('07/24', 1),
#  ('07/17', 1),
#  ('07/13', 1),
#  ('07/11', 1),
#  ('07/08', 1),
#  ('07/07', 1),
#  ('07/04', 1),
#  ('06/20', 1),
#  ('06/10', 1),
#  ('05/14', 1),
#  ('05/13', 1),
#  ('05/01', 1),
#  ('04/17', 1),
#  ('04/16', 1),
#  ('04/05', 1),
#  ('04/03', 1),
#  ('04/02', 1),
#  ('03/25', 1),
#  ('03/21', 1),
#  ('03/17', 1),
#  ('03/12', 1),
#  ('03/06', 1),
#  ('03/02', 1),
#  ('02/18', 1),
#  ('02/17', 1),
#  ('02/13', 1),
#  ('02/12', 1),
#  ('02/06', 1),
#  ('02/03', 1),
#  ('01/24', 1),
#  ('01/21', 1),
#  ('01/19', 1),
#  ('01/07', 1),
#  ('01/06', 1)]

# %%
# %%sql
# /* There are no dates which would be outliers. Lets look, how are statistics by months */
#
# SELECT
# strftime('%m',birth_date) AS birthday_month,
# COUNT(*) AS nr_people
# FROM nobel
# WHERE birthday_month IS NOT NULL
# GROUP BY birthday_month
# ORDER BY nr_people DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('09', 91),
#  ('06', 90),
#  ('10', 88),
#  ('05', 87),
#  ('08', 83),
#  ('07', 79),
#  ('12', 78),
#  ('04', 77),
#  ('03', 77),
#  ('01', 74),
#  ('11', 71),
#  ('02', 61)]

# %%
# %%sql
# /* How are statistics by day of month? */
#
# SELECT
# strftime('%d',birth_date) AS birthday_day,
# COUNT(*) AS nr_people
# FROM nobel
# WHERE birthday_day IS NOT NULL
# GROUP BY birthday_day
# ORDER BY nr_people DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('23', 42),
#  ('15', 41),
#  ('30', 39),
#  ('28', 39),
#  ('19', 37),
#  ('01', 36),
#  ('22', 35),
#  ('07', 34),
#  ('27', 33),
#  ('21', 33),
#  ('20', 33),
#  ('06', 33),
#  ('25', 32),
#  ('10', 32),
#  ('18', 31),
#  ('08', 31),
#  ('29', 30),
#  ('09', 30),
#  ('26', 29),
#  ('24', 29),
#  ('13', 29),
#  ('12', 29),
#  ('14', 28),
#  ('03', 27),
#  ('16', 26),
#  ('05', 26),
#  ('02', 26),
#  ('31', 24),
#  ('11', 24),
#  ('04', 21),
#  ('17', 17)]

# %%
# %%sql
# /* Finally, how are statistics by day of week? */
#
# SELECT
#   case cast (strftime('%w', birth_date) as integer)
#   WHEN 0 then 'Sunday'
#   WHEN 1 then 'Monday'
#   WHEN 2 then 'Tuesday'
#   WHEN 3 then 'Wednesday'
#   WHEN 4 then 'Thursday'
#   WHEN 5 then 'Friday'
#   ELSE 'Saturday' END AS birth_weekday,
# COUNT(*) AS nr_people
# FROM nobel
# WHERE birth_date IS NOT NULL
# GROUP BY birth_weekday
# ORDER BY nr_people DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Saturday', 165),
#  ('Tuesday', 145),
#  ('Wednesday', 139),
#  ('Monday', 135),
#  ('Thursday', 133),
#  ('Friday', 130),
#  ('Sunday', 121)]

# %% [markdown]
# ### Summary for birthdays
# We have found that 28th February was the most common birthday between all laureates. Exactly eight people was born on that day. Nevertheless, there are many other dates on which was celebrating birthdays seven or six laureates.
#
# Statistics for months are more interesting. It is no surprise that the least laureates was born in the shortest month, February. However, the difference from other months is too large to be explained by 2-3 missing days in comparison to other months. Clearly, we would have to take in count statistics for birth rate to find out if there is born statisticaly more Nobel laureates in any month. But let's take it easy and look the numbers as they are. Most of laureates was born in June and September which have actually only 30 days.
#
# Further, there are quite large differences between days of month. The highest number of laureates was born on 23rd (42 laureates). One would expect that the lowest number would be born on 31st (24 laureates) but the lowest number was actually born on 17th (17 laureates). There is no reason to think that any date is better than other and the differences seems to follow normal distribution. We can assume that numbers for each date would be more similar if there would multiple times more laureates than we have today.
#
# Finally, for days of week we have only seven options and with almost 1000 of individuals with valid birth date we would expect that numbers for each day could be very similar. Nevertheless, there is much larger amount of laureates born on Saturdays, exactly 165 which is 20 more then on the second most popular day, Tuesday. Then it seems not lucky to be born on Sunday if you want to win a Nobel Prize. On the other hand, as discussed above, the number of laureates is not huge and differences between days of week can be random.

# %%
# %%sql
# /* As we have analyse statistics related to exact dates of birth, we can now
# do the above discussed update for birth dates which has a format YYYY-00-00.
# We will substitute the 'month-day' part for first July which is almost exactly in the middle of the year.
# Therefore, the new arbitrary dates will cause maximum six month error in the further calculations.
# First, we can check which laureates will be edited. */
#
# SELECT
# birth_date,
# laureate_id,
# strftime('%Y',birth_date) AS year_born,
# full_name
# FROM nobel
# WHERE birth_date IS NOT NULL AND year_born IS NULL
# ORDER BY birth_date;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('1943-00-00', 1030, None, 'Louis Brus'),
#  ('1945-00-00', 1031, None, 'Aleksey Yekimov'),
#  ('1946-00-00', 1034, None, 'Claudia Goldin'),
#  ('1948-00-00', 1004, None, 'Abdulrazak Gurnah'),
#  ('1949-00-00', 986, None, 'Michael Houghton'),
#  ('1954-00-00', 1016, None, 'Morten Meldal'),
#  ('1955-00-00', 969, None, 'Paul M. Romer'),
#  ('1956-00-00', 1007, None, 'David Card'),
#  ('1961-00-00', 1006, None, 'Dmitry Muratov'),
#  ('1961-00-00', 1029, None, 'Moungi Bawendi'),
#  ('1967-00-00', 998, None, 'Ardem Patapoutian'),
#  ('1993-00-00', 967, None, 'Nadia Murad')]

# %%
# %%sql
# /* Do the update of birth_date! */
#
# UPDATE nobel
# SET birth_date = substr(birth_date, 1, 4) || '-07-01'
# WHERE laureate_id IN (SELECT laureate_id FROM nobel WHERE birth_date IS NOT NULL AND strftime('%Y',birth_date) IS NULL);
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# []

# %%
# %%sql
# /* Check the result of update. There should be no record for the conditions now. */
#
# SELECT
# birth_date,
# strftime('%Y',birth_date) AS year_born,
# full_name
# FROM nobel
# WHERE birth_date IS NOT NULL AND year_born IS NULL
# ORDER BY birth_date;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# []

# %%
# %%sql
# /* Now we can check laureates born on first July. */
#
# SELECT
# birth_date,
# strftime('%m/%d',birth_date) AS date_born,
# full_name
# FROM nobel
# WHERE date_born = '07/01'
# ORDER BY birth_date;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('1879-07-01', '07/01', 'Léon Jouhaux'),
#  ('1927-07-01', '07/01', 'Robert W. Fogel'),
#  ('1929-07-01', '07/01', 'Gerald M. Edelman'),
#  ('1941-07-01', '07/01', 'Alfred G. Gilman'),
#  ('1941-07-01', '07/01', 'Myron S. Scholes'),
#  ('1943-07-01', '07/01', 'Louis Brus'),
#  ('1945-07-01', '07/01', 'Aleksey Yekimov'),
#  ('1946-07-01', '07/01', 'Claudia Goldin'),
#  ('1948-07-01', '07/01', 'Abdulrazak Gurnah'),
#  ('1949-07-01', '07/01', 'Michael Houghton'),
#  ('1954-07-01', '07/01', 'Morten Meldal'),
#  ('1955-07-01', '07/01', 'Paul M. Romer'),
#  ('1956-07-01', '07/01', 'David Card'),
#  ('1961-07-01', '07/01', 'Dmitry Muratov'),
#  ('1961-07-01', '07/01', 'Moungi Bawendi'),
#  ('1967-07-01', '07/01', 'Ardem Patapoutian'),
#  ('1993-07-01', '07/01', 'Nadia Murad')]

# %% [markdown]
# ### What is the average age of Nobel laureates and other age related statistics
# Now, our data were cleaned in the birth_date column and we can use it to calculate age related statistics.

# %%
# %%sql
# /* Who was the earliest and the latest born laureate so far? */
# SELECT
#     full_name,
#     sex,
#     category,
#     birth_country,
#     birth_date,
#     year AS year_awarded,
#     motivation
# FROM nobel
# WHERE birth_date = (SELECT MIN(birth_date) FROM nobel)
# OR birth_date = (SELECT MAX(birth_date) FROM nobel);
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Christian Matthias Theodor Mommsen', 'Male', 'Literature', 'Schleswig (Germany)', '1817-11-30', 1902, '"the greatest living master of the art of historical writing, with special reference to his monumental work, <I>A history of Rome</I>"'),
#  ('Malala Yousafzai', 'Female', 'Peace', 'Pakistan', '1997-07-12', 2014, '"for their struggle against the suppression of children and young people and for the right of all children to education"')]

# %%
# %%sql
# /* What is average age of laureates by category since year 1901? */
#
# SELECT
#     category,
#     ROUND(AVG(year - strftime('%Y', birth_date)),1) AS age_when_awarded
# FROM nobel
# GROUP BY category
# ORDER BY age_when_awarded DESC;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Economics', 66.9),
#  ('Literature', 65.0),
#  ('Peace', 60.8),
#  ('Chemistry', 59.1),
#  ('Medicine', 58.7),
#  ('Physics', 57.3)]

# %%
# %%sql
# /* What was average age of laureates when they were awarded and how was this number changing in time (by decades)? */
#
# SELECT
#   CAST(FLOOR(year / 10) * 10 AS TEXT) || 's' AS decade,
#     ROUND(AVG(year - strftime('%Y', birth_date)),1) AS age_when_awarded
# FROM nobel
# GROUP BY decade;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('1900s', 57.8),
#  ('1910s', 52.8),
#  ('1920s', 55.0),
#  ('1930s', 51.6),
#  ('1940s', 58.0),
#  ('1950s', 54.3),
#  ('1960s', 56.5),
#  ('1970s', 59.4),
#  ('1980s', 60.5),
#  ('1990s', 62.1),
#  ('2000s', 65.9),
#  ('2010s', 67.0),
#  ('2020s', 68.8)]

# %%
# %%sql
# /* Lets check, how was the average age in each category changing through the decades. */
#
# SELECT
#   CAST(FLOOR(year / 10) * 10 AS TEXT) || 's' AS decade,
#     ROUND(AVG(CASE WHEN category='Physics' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Physics,
#     ROUND(AVG(CASE WHEN category='Chemistry' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Chemistry,
#     ROUND(AVG(CASE WHEN category='Medicine' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Medicine,
#     ROUND(AVG(CASE WHEN category='Literature' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Literature,
#     ROUND(AVG(CASE WHEN category='Peace' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Peace,
#     ROUND(AVG(CASE WHEN category='Economics' THEN year-strftime('%Y', birth_date) ELSE NULL END),1) AS Economics
# FROM nobel
# GROUP BY decade;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('1900s', 49.2, 51.0, 56.0, 64.9, 67.3, None),
#  ('1910s', 48.1, 49.0, 49.2, 59.0, 61.8, None),
#  ('1920s', 45.6, 52.3, 53.9, 60.1, 64.1, None),
#  ('1930s', 41.3, 46.0, 54.7, 56.4, 64.1, None),
#  ('1940s', 51.1, 54.4, 56.0, 64.3, 75.8, None),
#  ('1950s', 49.8, 53.0, 51.8, 63.7, 63.7, None),
#  ('1960s', 50.2, 55.8, 55.0, 67.0, 59.0, 70.0),
#  ('1970s', 53.7, 61.9, 56.7, 67.3, 56.8, 67.0),
#  ('1980s', 59.4, 56.2, 60.7, 67.6, 56.4, 67.9),
#  ('1990s', 60.0, 63.1, 60.5, 67.5, 58.7, 65.5),
#  ('2000s', 68.5, 65.3, 63.5, 66.4, 64.3, 66.9),
#  ('2010s', 68.3, 71.1, 68.3, 70.0, 47.2, 66.5),
#  ('2020s', 75.4, 63.9, 67.9, 74.0, 57.3, 69.0)]

# %%
# %%sql
# /* Who was the oldest when awarded? */
#
# SELECT
#     year - strftime('%Y', birth_date) AS age_when_awarded,
#     full_name,
#     year,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE age_when_awarded IS NOT NULL
# ORDER BY age_when_awarded DESC
# LIMIT 5;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(97, 'John Goodenough', 2019, 'Chemistry', '"for the development of lithium-ion batteries"', 'Germany', 'United States of America'),
#  (96, 'Arthur Ashkin', 2018, 'Physics', '"for the optical tweezers and their application to biological systems"', 'USA', 'United States of America'),
#  (90, 'Leonid Hurwicz', 2007, 'Economics', '"for having laid the foundations of mechanism design theory"', 'Russia', 'United States of America'),
#  (90, 'Syukuro Manabe', 2021, 'Physics', '"for the physical modelling of Earth’s climate quantifying variability and reliably predicting global warming"', 'Japan', 'United States of America'),
#  (90, 'Klaus Hasselmann', 2021, 'Physics', '"for the physical modelling of Earth’s climate quantifying variability and reliably predicting global warming"', 'Germany', 'Germany')]

# %%
# %%sql
# /* Who was the youngest when awarded? */
#
# SELECT
#     year - strftime('%Y', birth_date) AS age_when_awarded,
#     full_name,
#     year,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE age_when_awarded IS NOT NULL
# ORDER BY age_when_awarded ASC
# LIMIT 5;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(17, 'Malala Yousafzai', 2014, 'Peace', '"for their struggle against the suppression of children and young people and for the right of all children to education"', 'Pakistan', None),
#  (25, 'William Lawrence Bragg', 1915, 'Physics', '"for their services in the analysis of crystal structure by means of X-rays"', 'Australia', 'United Kingdom'),
#  (25, 'Nadia Murad', 2018, 'Peace', '"for their efforts to end the use of sexual violence as a weapon of war and armed conflict"', 'Iraq', None),
#  (31, 'Werner Karl Heisenberg', 1932, 'Physics', '"for the creation of quantum mechanics, the application of which has, inter alia, led to the discovery of the allotropic forms of hydrogen"', 'Germany', 'Germany'),
#  (31, 'Paul Adrien Maurice Dirac', 1933, 'Physics', '"for the discovery of new productive forms of atomic theory"', 'United Kingdom', 'United Kingdom')]

# %%
# %%sql
# /* Which Nobel laureates had the shortest life? */
#
# SELECT
#     ROUND((julianday(death_date) - julianday(birth_date))/365.2422,1) AS life_length,
#     full_name,
#     year AS year_awarded,
#     strftime('%Y', death_date) AS year_of_death,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE life_length IS NOT NULL
# ORDER BY life_length ASC
# LIMIT 5;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(39.2, 'Martin Luther King Jr.', 1964, '1968', 'Peace', None, 'United States of America', None),
#  (43.8, 'Niels Ryberg Finsen', 1903, '1904', 'Medicine', '"in recognition of his contribution to the treatment of diseases, especially lupus vulgaris, with concentrated light radiation, whereby he has opened a new avenue for medical science"', 'Faroe Islands (Denmark)', 'Denmark'),
#  (46.2, 'Albert Camus', 1957, '1960', 'Literature', '"for his important literary production, which with clear-sighted earnestness illuminates the problems of the human conscience in our times"', 'French Algeria (Algeria)', None),
#  (46.9, 'Pierre Curie', 1903, '1906', 'Physics', '"in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"', 'France', 'France'),
#  (48.6, 'Carl von Ossietzky', 1935, '1938', 'Peace', None, 'Germany', None)]

# %%
# %%sql
# /* Which of deceased Nobel laureates had the longest life so far? */
#
# SELECT
#     ROUND((julianday(death_date) - julianday(birth_date))/365.2422,1) AS life_length,
#     full_name,
#     year AS year_awarded,
#     strftime('%Y', death_date) AS year_of_death,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE life_length IS NOT NULL
# ORDER BY life_length DESC
# LIMIT 5;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(103.7, 'Rita Levi-Montalcini', 1986, '2012', 'Medicine', '"for their discoveries of growth factors"', 'Italy', 'Italy'),
#  (102.7, 'Ronald H. Coase', 1991, '2013', 'Economics', '"for his discovery and clarification of the significance of transaction costs and property rights for the institutional structure and functioning of the economy"', 'United Kingdom', 'United States of America'),
#  (100.9, 'John Goodenough', 2019, '2023', 'Chemistry', '"for the development of lithium-ion batteries"', 'Germany', 'United States of America'),
#  (99.5, 'Charles Hard Townes', 1964, '2015', 'Physics', '"for fundamental work in the field of quantum electronics, which has led to the construction of oscillators and amplifiers based on the maser-laser principle"', 'United States of America', 'United States of America'),
#  (99.4, 'Maurice Allais', 1988, '2010', 'Economics', '"for his pioneering contributions to the theory of markets and efficient utilization of resources"', 'France', 'France')]

# %%
# %%sql
# /* Who are the oldest currently living laureates and how old are they? */
#
# SELECT
#     full_name,
#     birth_date,
#     year AS year_awarded,
#     ROUND(year - strftime('%Y', birth_date),0) AS age_when_awarded,
#     ROUND((julianday('now') - julianday(birth_date))/365.2422,1) AS current_age,
#     category,
#     motivation,
#     birth_country,
#     organization_country
# FROM nobel
# WHERE death_date IS NULL AND birth_date IS NOT NULL
# ORDER BY current_age DESC
# LIMIT 5;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Paul D. Boyer', '1918-07-31', 1997, 79.0, 105.6, 'Chemistry', '"for their elucidation of the enzymatic mechanism underlying the synthesis of adenosine triphosphate (ATP)"', 'United States of America', 'United States of America'),
#  ('Jens C. Skou', '1918-10-08', 1997, 79.0, 105.4, 'Chemistry', '"for the first discovery of an ion-transporting enzyme, Na+, K+ -ATPase"', 'Denmark', 'Denmark'),
#  ('Nicolaas Bloembergen', '1920-03-11', 1981, 61.0, 104.0, 'Physics', '"for their contribution to the development of laser spectroscopy"', 'Netherlands', 'United States of America'),
#  ('Edmond H. Fischer', '1920-04-06', 1992, 72.0, 103.9, 'Medicine', '"for their discoveries concerning reversible protein phosphorylation as a biological regulatory mechanism"', 'China', 'United States of America'),
#  ('Jack Steinberger', '1921-05-25', 1988, 67.0, 102.8, 'Physics', '"for the neutrino beam method and the demonstration of the doublet structure of the leptons through the discovery of the muon neutrino"', 'Germany', 'Switzerland')]

# %%
# %%sql
# /* Unfortunately, after quick check of nymes by google, it seems that all,
# supposedly living laureates, in the previous table are actually deceased.
# This means that death dates are not updated frequently or properly in the Noble dataset
# and we cannot rely that missing values means that laureate is still alive.
#
# However, lets assume for a moment that the Nobel dataset is up to date and count
# how many living laureates are over age of 90. */
#
# SELECT
#     COUNT(*) AS living_winners_over_age_90
# FROM nobel
# WHERE death_date IS NULL
# AND birth_date IS NOT NULL
# AND ((julianday('now') - julianday(birth_date))/365.2422)>90;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [(90,)]

# %%
# %%sql
# /* As shown earlier, most people becomes laureates in a age where most of us finishing our careers.
# Lets look who enjoyed to be Nobel laureate longest.
# In other words who lived (or still lives) longest after being awarded.
# Note: M.Eigen and M. Gell-Mann does not have death date in the Nobel dataset
# and they were removed after checking their death dates and calculating real value
# for years_lived_since_awarded which was too low to provide them place in this "TOP 10" */
#
# SELECT
#     full_name,
#     birth_date,
#     year AS year_awarded,
#     ROUND(year - strftime('%Y', birth_date),0) AS age_when_awarded,
#     CASE WHEN death_date IS NULL THEN 'alive'
#     WHEN death_date IS NOT NULL THEN 'deceased' END AS dead_or_alive,
#     CASE WHEN death_date IS NULL THEN ROUND((julianday('now') - julianday(birth_date))/365.2422,1)
#     WHEN death_date IS NOT NULL THEN ROUND((julianday(death_date) - julianday(birth_date))/365.2422,1) END AS life_length,
#     CASE WHEN death_date IS NULL THEN (strftime('%Y', 'now') - year)
#     WHEN death_date IS NOT NULL THEN (strftime('%Y', death_date) - year) END AS years_lived_since_awarded,
#     category
# FROM nobel
# WHERE birth_date IS NOT NULL AND full_name NOT IN ('Manfred Eigen', 'Murray Gell-Mann')
# ORDER BY years_lived_since_awarded DESC
# LIMIT 10;
# Out:
#  * sqlite:///jupyter_sql_nobel.db
# Done.
# [('Chen Ning Yang', '1922-09-22', 1957, 35.0, 'alive', 101.5, 67, 'Physics'),
#  ('Tsung-Dao (T.D.) Lee', '1926-11-24', 1957, 31.0, 'alive', 97.3, 67, 'Physics'),
#  ('James Dewey Watson', '1928-04-06', 1962, 34.0, 'alive', 95.9, 62, 'Medicine'),
#  ('Prince Louis-Victor Pierre Raymond de Broglie', '1892-08-15', 1929, 37.0, 'deceased', 94.6, 58, 'Physics'),
#  ('William Lawrence Bragg', '1890-03-31', 1915, 25.0, 'deceased', 81.3, 56, 'Physics'),
#  ('Adolf Friedrich Johann Butenandt', '1903-03-24', 1939, 36.0, 'deceased', 91.8, 56, 'Chemistry'),
#  ('Archibald Vivian Hill', '1886-09-26', 1922, 36.0, 'deceased', 90.7, 55, 'Medicine'),
#  ('Carl David Anderson', '1905-09-03', 1936, 31.0, 'deceased', 85.4, 55, 'Physics'),
#  ('Frederick Sanger', '1918-08-13', 1958, 40.0, 'deceased', 95.3, 55, 'Chemistry'),
#  ('Karl Manne Georg Siegbahn', '1886-12-03', 1924, 38.0, 'deceased', 91.8, 54, 'Physics')]

# %% [markdown]
# ## Conclusions
# In this notebook, we employed SQLite to analyse Nobel Prize Dataset. Data was imported from csv file and database was created. Then we checked data if any cleaning is necessary. This was done by focusing on birth and death dates and also by checking count of missing values in each column. Mostly, there was simple and clear explanations for missing values but there were some faulty birth dates which we substituted (updated) for first July. In the analysis, the main focus was on number of laureates and organizations awarded in different countries and later we calculated various statistics related to age. The effort to find the oldest currently living laureate helped us to find out that death dates in the Nobel dataset are often missing.
#
# In summary, we can say that USA is the most successful country from the point of laureates born or working in there. Also, it seems that laureates are usually awarded in rather older age and quite a number of them lived very long lives.
